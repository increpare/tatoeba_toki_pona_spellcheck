# %% [markdown]
# <a href="https://colab.research.google.com/github/increpare/tatoeba_toki_pona_spellcheck/blob/main/tatoeba_turkish_spellcheck.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
replacements = """
...çca -> ...çça
...çce -> ...ççe
...çda -> ...çta
...çdan -> ...çtan
...çde -> ...çte
...çden -> ...çten
...fda -> ...fta
...fdan -> ...ftan
...fde -> ...fte
...fden -> ...ften
...hda -> ...hta
...hdan -> ...htan
...hden -> ...hten
...kca -> ...kça
...kce -> ...kçe
...kda -> ...kta
...kdan -> ...ktan
...pca -> ...pça
...pce -> ...pçe
...pda -> ...pta
...pdan -> ...ptan
...pde -> ...pte
...pden -> ...pten
...sda -> ...sta
...sdan -> ...stan
...sde -> ...ste
...sden -> ...sten
...şca -> ...şça
...şce -> ...şçe
...şde -> ...şte
...şden -> ...şten
acenta... -> acente...
aç gözlü... -> açgözlü...
açıkca... -> açıkça...
adele... -> adale...
afedersin... -> affedersin...
aksesuvar... -> aksesuar...
aktrist... -> aktris...
akıl almaz... -> akılalmaz...
alaman... -> alman...
allerji... -> alerji...
alt üst... -> altüst...
alış veriş... -> alışveriş...
aliminyum... -> alüminyum...
ambülans... -> ambulans
ampül... -> ampul...
ana okulu... -> anaokulu...
antreman... -> antrenman...
apandist... -> apandisit...
aperatif... -> aperitif...
arabça... -> arapça...
arasıra... -> ara sıra...
ardarda... -> art arda...
arjentin... -> arjantin...
atmış... -> altmış... (çoğu false positive)
avusturalya... -> avustralya...
ayırım... -> ayrım...
azarbaycan... -> azerbaycan
azarbeycan... -> azerbaycan
azerbeycan... -> azerbaycan
banço... -> banjo...
başbaşa... -> baş başa...
başı boş... -> başıboş...
belkide... -> belki de...
benle... -> benimle...
beysbol... -> beyzbol...
bir kaç... -> birkaç...
bir çok... -> birçok...
birarada... -> bir arada...
birden bire... -> birdenbire...
biritan... -> britan...
birsürü... -> bir sürü...
brazilya... -> brezilya...
bu gün... -> bugün...
bugünki... -> bugünkü...
bulüz... -> bluz...
burda... -> burada...
buyrun... -> buyurun...
büfte... -> bifte...
büyük anne... -> büyükanne...
büyük baba... -> büyükbaba...
can kurtaran... -> cankurtaran...
cimnastik... -> jimnastik...
çarşanba... -> çarşamba...
çeki düzen... -> çekidüzen...
çokaz... -> çok az...
çoşku... -> coşku...
dahada... -> daha da...
deniz aşırı... -> denizaşırı...
değilmi... -> değil mi...
deyer... -> değer...
deyme... -> değme...
doğumgünü... -> doğum günü...
döküman... -> doküman...
döğdü... -> dövdü...
döğüş... -> dövüş...
dünki... -> dünkü...
düz taban... -> düztaban...
eczahane... -> eczane...
eksoz... -> egzoz...
elele... -> el ele...
entellektüel... -> entelektüel...
eposta... -> e-posta...
eylence... -> eğlence...
eylenmek... -> eğlenmek...
fantazi... -> fantezi...
farked... -> fark ed...
farket... -> fark et...
farzed... -> farz ed...
farzet... -> farz et...
fırans... -> frans...
filim... -> film...
fonksyon... -> fonksiyon...
fotograf... -> fotoğraf...
gardrop... -> gardırop...
gurup... -> grup...
gök kuşağı... -> gökkuşağı...
gök yüzü... -> gökyüzü...
göz yaşı... -> gözyaşı...
gözardı... -> göz ardı...
gözkulak... -> göz kulak...
gözüpek... -> gözü pek...
haftasonu... -> hafta sonu...
haked... -> hak ed...
haket... -> hak et...
hakket... -> hak et...
halbu ki... -> halbuki...
hastahane... -> hastane...
hava alanı... -> havaalanı...
hava limanı... -> havalimanı...
hem fikir... -> hemfikir...
hemde... -> hem de...
her hangi... -> herhangi...
hergün... -> her gün...
herkez... -> herkes...
herne... -> her ne...
heryer... -> her yer...
herzaman... -> her zaman...
herşey... -> her şey...
hiç bir... -> hiçbir...
hiçkimse... -> hiç kimse...
hiçte... -> hiç de...
humani... -> hümani...
ısraf... -> israf...
iki yüzlü... -> ikiyüzlü...
ilk okul... -> ilkokul...
insan oğlu... -> insanoğlu...
insiyatif... -> inisiyatif...
israr... -> ısrar...
istakoz... -> ıstakoz...
istambul... -> istanbul...
itibariyle... -> itibarıyla...
iyiki... -> iyi ki...
kamu oyu... -> kamuoyu...
kapşon... -> kapüşon...
kareografi... -> koreografi...
kaysı... -> kayısı...
klavuz... -> kılavuz...
klüp... -> kulüp...
kolleksiyon... -> koleksiyon...
kominist... -> komünist...
kompartman... -> kompartıman...
koperatif... -> kooperatif...
kılınç... -> kılıç...
kıral... -> kral...
kıraliyet... -> kraliyet...
kıraliçe... -> kraliçe...
kırallık... -> krallık...
kızarkadaş... -> kız arkadaş...
kızkardeş... -> kız kardeş...
kürdçe... -> kürtçe...
labaratuar... -> laboratuvar...
labaratuvar... -> laboratuvar...
madem ki... -> mademki...
mahçup... -> mahcup...
makina... -> makine...
malesef... -> maalesef...
malolmak... -> mal olmak...
marry... -> mary...
mary'e... -> mary'ye...
mary'i... -> mary'yi...
mary'le... -> mary'yle...
matamatik... -> matematik...
menejer... -> menajer...
metod... -> metot...
meyva... -> meyve...
meşkul... -> meşgul...
motorsiklet... -> motosiklet...
müdahele... -> müdahale...
müsade... -> müsaade...
müstehak... -> müstahak...
mütevazi... -> mütevazı...
nerde... -> nerede...
neyseki... -> neyse ki...
nufus... -> nüfus...
okur yazar... -> okuryazar...
onaltı... -> on altı...
onbeş... -> on beş...
onbir... -> on bir...
ondokuz... -> on dokuz...
ondört... -> on dört...
oniki... -> on iki...
onla... -> onunla...
onsekiz... -> on sekiz...
onyedi... -> on yedi...
onüç... -> on üç...
orda... -> orada...
orjinal... -> orijinal...
orta okul... -> ortaokul...
oysa ki... -> oysaki...
pantalon... -> pantolon...
parlemento... -> parlamento...
pastahane... -> pastane...
pekaz... -> pek az...
pekçok... -> pek çok...
penbe... -> pembe...
perşenbe... -> perşembe...
peşpeşe... -> peş peşe...
pilaj... -> plaj...
postahane... -> postane...
proğram... -> program...
rasgele... -> rastgele...
rasgelmek... -> rast gelmek...
raslantı... -> rastlantı...
sarfed... -> sarf ed...
sarfet... -> sarf et...
sarmısak... -> sarımsak...
senle... -> seninle...
sivri sinek... -> sivrisinek...
sohpet... -> sohbet...
sueter... -> süveter...
süpriz... -> sürpriz...
şöför... -> şoför...
tabi ki... -> tabii ki...
taktir... -> takdir...
terked... -> terk ed...
terket... -> terk et...
tesbih... -> tespih...
tesbit... -> tespit...
traş... -> tıraş...
türküye... -> türkiye...
umru... -> umuru...
ünüversite... -> üniversite...
ünvan... -> unvan...
vaz geç... -> vazgeç...
yada... -> ya da...
yanlız... -> yalnız...
yanyana... -> yan yana...
yanısıra... -> yanı sıra...
yinede... -> yine de...
yüksek okul... -> yüksekokul...
yüz ölçüm... -> yüzölçüm...
zıttı... -> zıddı...
"""

# %%
import re

change_lines = replacements.split("\n")

change_lines = [ line.strip() for line in change_lines if not len(line.strip())==0]

#filtering out asterisks "We have two Turkish language associations and they have differences of opinion about spelling of some words and that word is one of them. I put an asterisk at the beginning of them to indicate that. I now replaced them with ※ to avoid confusion."
replacements_noasterisk = [ line for line in change_lines if not "*" in line ]



replacements_simple = [ line for line in replacements_noasterisk if (not "/" in line) and (not "..." in line)]
replacements_multi = [ line for line in replacements_noasterisk if ("/" in line)]

regex_start = re.compile(r"\b\.\.\.\B")
replacements_regex_start = [ line for line in replacements_noasterisk if bool(regex_start.search(line))]

regex_end = re.compile(r"\B\.\.\.\b")
replacements_regex_end = [ line for line in replacements_noasterisk if bool(regex_end.search(line))]


def toLower_turkish(s):
  s = s.replace("I", "ı")
  s = s.replace("İ", "i")
  return s.lower()

def parseline(l):
  lr = l.split("->")
  src = toLower_turkish(lr[0].strip())
  dst = lr[1].strip()
  bracket_index = dst.find("(")  
  if bracket_index>=0:
    cleave = dst.split("(")
    dst = cleave[0].strip()
  return {"src":src,"dst":dst,"message":l}

change_lines = replacements.split("\n")

replacement_rules = []



# simple rules A -> B
for line in replacements_simple:
  parsed = parseline(line)
  regex = re.compile(r"\b"+parsed["src"]+r"\b")
  replacement_rules.append({
      "regex":regex,
      "change_from":parsed["src"],
      "change_to":parsed["dst"],
      "message":parsed["message"]
  }) 


#1 rules like "A/B -> C" or "A/B/C -> D/E/F"

for line in replacements_multi:
  parsed = parseline(line)
  change_from=parsed["src"]
  change_to=parsed["dst"]
  
  from_parts=change_from.split("/")
  to_parts=change_to.split("/")
    
  #rules like "Labaratuar/Labaratuvar -> Laboratuvar"
  if len(from_parts)>0 and len(to_parts)==1:
    for from_part in from_parts:
      regex = re.compile(r"\b"+from_part+r"\b")
      replacement_rules.append({
          "regex":regex,
          "change_from":from_part.strip(),
          "change_to":change_to,
          "message":parsed["message"]
      }) 
  elif len(from_parts)==len(to_parts):
    i=0
    while i<len(from_parts):
        from_part = from_parts[i].strip()
        to_part = to_parts[i].strip()
        regex = re.compile(r"\b"+from_part+r"\b")
        replacement_rules.append({
          "regex":regex,
          "change_from":from_part,
          "change_to":to_part,
          "message":parsed["message"]
        }) 
        
        i=i+1
  else:
    print("don't know how to interpret rule '"+parsed["message"]+"'.")



    
# suffix rules ...A -> ...B
for line in replacements_regex_end:
  parsed = parseline(line)
  change_from=parsed["src"].replace("...","")
  regex = re.compile(change_from+r"\b")
  replacement_rules.append({
      "regex":regex,
      "change_from":parsed["src"],
      "change_to":parsed["dst"],
      "message":parsed["message"]
  }) 
   
# prefix rules ...A -> ...B
for line in replacements_regex_start:
  parsed = parseline(line)
  change_from=parsed["src"].replace("...","")
  regex = re.compile(r"\b"+change_from)
  replacement_rules.append({
      "regex":regex,
      "change_from":parsed["src"],
      "change_to":parsed["dst"],
      "message":parsed["message"]
  })

# %%
# !pip install emoji

import os
import urllib.request
from IPython.display import Markdown, display
from emoji import UNICODE_EMOJI
# Out:
# Collecting emoji
#   Downloading https://files.pythonhosted.org/packages/ff/1c/1f1457fe52d0b30cbeebfd578483cedb3e3619108d2d5a21380dfecf8ffd/emoji-0.6.0.tar.gz (51kB)
#      |████████████████████████████████| 51kB 2.7MB/s
# Building wheels for collected packages: emoji
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-0.6.0-cp36-none-any.whl size=49716 sha256=3914eeba0c547e0d83088858782a27864345937c30e5fa7d499c204093b95869
#   Stored in directory: /root/.cache/pip/wheels/46/2c/8b/9dcf5216ca68e14e0320e283692dce8ae321cdc01e73e17796
# Successfully built emoji
# Installing collected packages: emoji
# Successfully installed emoji-0.6.0

# %%
print("downloading Turkish sentences from tatoeba")
urllib.request.urlretrieve('https://downloads.tatoeba.org/exports/per_language/tur/tur_sentences_detailed.tsv.bz2', 'tur_sentences_detailed.tsv.bz2')

# !rm -rf /content/tur_sentences_detailed.tsv

print("decompressing data")
# !bunzip2 /content/tur_sentences_detailed.tsv.bz2
print("done")
# Out:
# downloading Turkish sentences from tatoeba
# decompressing data
# done

# %%
import re
import pandas as pd
from io import StringIO

df = pd.read_csv("/content/tur_sentences_detailed.tsv",names=["k","v","user","added","modified"],delimiter="\t",quoting=3)

# %%
def has_emoji(s):
    count = 0
    for emoji in UNICODE_EMOJI:
        count += s.count(emoji)
        if count >= 1:
            return True
    return False

errors={}

# checks for "mi/sina" li sentences, and roughly for sentences with an "e" but without a "li"/"o"/"mi"/"sina"
def validate_sentence(s,index,user):    
  s_lower=toLower_turkish(s)
  if user not in errors:
    errors[user]=[]

  for replacement_data in replacement_rules:
    regex=replacement_data["regex"]
    if regex.search(s_lower):
      errors[user].append([s,index,replacement_data["message"]])

    

freq={}
links={}
id_table={}

from ipywidgets import IntProgress
from IPython.display import display
f = IntProgress(min=0, max=len(df),description="searching...") # instantiate the bar

display(f) # display the bar

def printm(s):
  global output
  output=output+"\n"+s;
    
i=0
for index, row in df.iterrows():
  id_table[index]=row
  user = row['user']
  sentence=row['v']
  validate_sentence(sentence,index,user)
  i=i+1
  if (i%1000)==0:
        f.value=i

print("all sentences processed")

import datetime
from ipywidgets import IntProgress
from IPython.display import display

output="# Tatoeba Turkish Spellcheck Report\n\n"+str(datetime.datetime.now())+"\n\n"



for u in errors:
  errorlist = errors[u]
  if len(errorlist)==0:
    continue
  printm("\n")
  printm("***")
  printm(" \n")
  printm("### Likely Error report for user ["+u+"](https://tatoeba.org/eng/user/profile/"+u+").")
  printm("\n")
  for error in errorlist:
    printm(""+error[0]+"  ")
    printm("- "+str(error[2])+"  ")
    printm("- http://tatoeba.org/eng/sentences/show/"+str(error[1])+"  ")
    printm("")
printm("***")
display(Markdown(output))

print("done")
# Out:
# IntProgress(value=0, description='searching...', max=694417)
# all sentences processed
# # Tatoeba Turkish Spellcheck Report
#
# 2020-11-25 18:08:55.933096
#
#
#
#
# ***
#
#
# ### Likely Error report for user [Adopter](https://tatoeba.org/eng/user/profile/Adopter).
#
#
# Tatlı su balıkları arasındakilerden bazıları korunmaktadır. Onları yakalamak veya satın almak yasadışıdır.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/509248
#
# Asal sayılar hayata benzer, onlar tamamen mantıksaldır fakat, eğer tüm zamanınızı onun hakkında düşünmek için harcarsanız kurallarının bulunması imkânsızdır.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/585939
#
# Bir polis, kızlara arabanın onlara ait olup olmadığını sordu.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/825591
#
# Haydi bu konuda yeni sözcük haznesiyle cümleler bulun, yandaki _____ listesine onları ekleyin; ve çevirin.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/852103
#
# Onlar gülüştüler.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/4510480
#
#
#
# ***
#
#
# ### Likely Error report for user [ritualesatanum](https://tatoeba.org/eng/user/profile/ritualesatanum).
#
#
# Zaten onlardan biri sende var.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/8152928
#
# Onlar benim BMW'umu yakıp yıktılar!
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/8156637
#
# Onları bana verin!
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/8163413
#
# Onları nerede gördün?
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/8164863
#
# O çiçekleri onları iyice görebileceğimiz bir yere koy.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/8311020
#
# Onlar mağazada Elena için bir elbise seçiyorlar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/8311154
#
# Çiy, çiçeğin göz yaşıdır.
# - göz yaşı... -> gözyaşı...
# - http://tatoeba.org/eng/sentences/show/8315461
#
# Onlar benim kurallarım değil, Tom'un kuralları.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/8315465
#
# Onlar hastalar, yataklarında yatıyorlar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/8316033
#
# Onlar düşman değiller, onlar ortaklar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/8316084
#
# Onlar ırmakta yüzmüyorlar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/8316091
#
# Onlar pazartesiden pazara kadar Budapeşte'de olacaklar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/8349862
#
# O, onları sever.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/8352747
#
# Tom her gece Mary'i arıyor.
# - mary'i... -> mary'yi...
# - http://tatoeba.org/eng/sentences/show/8421700
#
#
#
# ***
#
#
# ### Likely Error report for user [duran](https://tatoeba.org/eng/user/profile/duran).
#
#
# Onlar plaja gitti.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/476847
#
# Onların kazanacağından eminim.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/479424
#
# Dima bir gecede 25 adamla yattı ve sonra onları öldürdü.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/489610
#
# Onlar arkadaş mı?
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/497544
#
# Onlar çukur kazıyor.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/499323
#
# Onlar çukur kazıyorlar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/499325
#
# Onlar burada acayip bir hayvan gördü.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/502152
#
# Onların ana dili Fransızca.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/508559
#
# Bazen, şeyler onlara farklı açılardan bakılınca daha güzeldir.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/509292
#
# Onlar genç iken evlendiler.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/511030
#
# Onlar davetimizi reddetti.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/513094
#
# Onlar iyi bir çifttir.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/522206
#
# Onlar hırsızı ağaca bağladılar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/522212
#
# Onların on iki çocuğu var.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/530724
#
# Onlar Olimpiyat Oyunları'na katılmak istiyorlar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/586528
#
# Onlar düğünün zamanını ve yerini belirlediler.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/603379
#
# Onlar uzun süredir burada yaşıyor.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/604532
#
# The Network'ün kasım meselesinde görünen raporunun 70 kopyasını üretmek ve onları ajanlarımıza dağıtmak mümkün mü?
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/604743
#
# Onların iki kız çocuğu var.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/633965
#
# Onlardan herhangi birini seçebilirsin.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/654576
#
# Onlar kazandılar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/656610
#
# Bazen onlarla buluşuyoruz.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/671216
#
# Onlar Noel Yortusu'nda evlendiler.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/671222
#
# Onlar onu şehrin en iyi doktoru olarak kabul ettiler.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/747242
#
# Onu onlara ver.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/756689
#
# Onlar kedilerine Tom ve Jerry adını verdiler.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/849832
#
# Onlar Greeley'i bir aptal ve bir hain olarak adlandırdı.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/850292
#
# O Pablo ile evleneceğini açıkça ilan ettiğinde, neredeyse büyük annesine kalp krizi geçirtecekti , halasının gözlerini yuvasından fırlattıracaktı fakat küçük kız kardeşi gururla baktı.
# - büyük anne... -> büyükanne...
# - http://tatoeba.org/eng/sentences/show/851224
#
# Onların hepsi sadece kızları götürmek için buradalar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/851268
#
# Onlar asla aynı fikirde olmayacaklar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/851716
#
# Onun arkadaşlarının hepsi vücut yastığıydılar,ve onunkilerinin hepsi oyuncak bebektiler;böylece bir ölüyü canlandırmaya olan düşkünlüklerine yapıştılar.Fakat onların cansız nesne olmamalarından fakat kompleks duyguları olan insanlardan dolayı onların ilişkileri bazen gergindi.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/851817
#
# Onların konuşmaları devam etti.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/851850
#
# Ray, Gary'nin hikayesini desteklemek istiyordu fakat polisler onların ikisininde gerçeği söylediklerine ikna olmamışlardı.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/854219
#
# Onlar mahkûmu serbest bıraktılar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/858321
#
# Bu günlerde çok meşgulüm!
# - bu gün... -> bugün...
# - http://tatoeba.org/eng/sentences/show/860768
#
# Onlar radyo dinliyorlar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/861398
#
# Onlarla uzlaşmaya çalıştık.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/863066
#
# Beş saat onları aradı.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/863079
#
# Onların rapora reaksiyonu neydi?
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/863212
#
# Onlar kitabın tüm kopyalarının imha edilmesini talep ettiler.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/863240
#
# Onlar spikeri gülerek susturdular.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/863542
#
# Şu ya da bu nedenle, onların Fransa'daki tatili onların olmasını umdukları kadar iyi değildi.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/864087
#
# Sanırım onlar ithalatlara ağır bir vergi koymalılar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/864773
#
# Onlar bir hakim atadılar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/864871
#
# Onların tartışması sonunda berabere bitti.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/865132
#
# Onların görüşleri arasında ince bir fark vardı.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/865137
#
# Sonra onur konuğu onları açar ve şükranlarını ifade eder.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/865170
#
# Bu konuda onlarla aynı fikirde olamam.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/865697
#
# Onlar otobüsten indiler ve sıcak güneşte iki kilometre yürüdüler.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/866892
#
# Onlar sanki müzikten büyülenmiş gibi sessiz oturdular.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/867395
#
# Onlar evi bir gün içerisinde yıkacaklar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/867398
#
# Onlar evi yapmak için altı ay harcadılar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/867402
#
# Onlar can sıkıcı işlerinden dolayı bitkindiler.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/867680
#
# Onlar yeni binada çalışmaktalar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/867681
#
# Onlar ne ticareti yapıyorlar?
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/867684
#
# Onlar Çin dominosunun keyfini çıkardılar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/867686
#
# Onların zamanında geleceğine inanabilirsin.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/867688
#
# Onların yardımına bel bağlayamazsın.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/867689
#
# Çok sayıda misafir vardı-onlardan çoğu bizim öğretmenin sınıf arkadaşları ve arkadaşlarıydı.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/867916
#
# Bize ve başka herkese bu günü hatırlatmak için, bizimle birlikte herkese bir ağaç dikmesini rica ediyorum.
# - bu gün... -> bugün...
# - http://tatoeba.org/eng/sentences/show/867933
#
# Onlar şarkı söyleyebilirler.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/889904
#
# Onlar, hayırseverleri olarak onu yüksek itibarda tuttu.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/922268
#
# Onlar onun dakikliğinden gurur duyuyordu.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/923234
#
# Onların iyi bir ekipmanı yoktu.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/927773
#
# Sevinç gözyaşları onların yanaklarından aktı.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/928813
#
# Onlar onu bir otorite olarak gördüler.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/930863
#
# Onların hepsi masum çocuklar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/939285
#
# Onlar bizim arabalarımız.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/939360
#
# Onlarınki eski bir aile.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/946502
#
# Onlar beni öldürecek.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1003734
#
# O, genç olduğu için, hasta büyük annesine özveriyle hizmet etti.
# - büyük anne... -> büyükanne...
# - http://tatoeba.org/eng/sentences/show/1006149
#
# Onların kararını etkileyen muhtemelen oydu.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1009384
#
# Çinli bayan arkadaşlarımın onları disipline sokmamdan hoşlandıklarını biliyorum.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1009748
#
# Nagasaki çevresinde onlara rehberlik edebilmem için kadınla birlikte gittim.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1012251
#
# Onların idamı için belirlenen günde, o sanki şölene gidiyormuş gibi saçını kesti ve giyinip kuşandı.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1012949
#
# Eğer yapmadığım bir şey için ailem beni cezalandırdıysa , onlara doğruları söylerdim ve benim masumiyetle ilgili onları ikna etmeye çalışırdım.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1014101
#
# Onlar dükkânda ithal mallar satıyorlar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1014824
#
# Onlar plaja gittiler.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1019581
#
# Onlar buluşmaları süresince kayak yapmaya gittiler.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1021305
#
# Sebzeleri yeme yerine, o, onları bir doğrayıcıya koyar ve onları içer.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1021420
#
# Bu tavuk bu günlerde hiç yumurtlamıyor.
# - bu gün... -> bugün...
# - http://tatoeba.org/eng/sentences/show/1022050
#
# Onların Yeni Zelanda'dadaki tüneller ile ilgili çok sayıda sorunları olduklarını duydum.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1022419
#
# Araba uçuruma gitmiş olsaydı onlar ölmüş olacaktı.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1022656
#
# Onlar onu mezarına gömdüler.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1022688
#
# Onlar düşman tarafından vurulma riskini göze almaya hazırdılar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1022850
#
# O, sadece İngilizce ve Almanca konuşur, onlardan hiçbirini anlamam.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1031393
#
# Anahtarlarımı masanın üstüne bıraktım. Onları bana getirir misin?
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1032024
#
# Bunlar gerçeklerdir. Onlar hakkında sıkı düşünün!
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1032030
#
# Nihayet, onlar kanla özgürlüğü satın aldı.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1032042
#
# Kesilmiş uzuvları olan insanlar onları hâlâ orada gibi hissetmeye devam ediyor.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1032218
#
# Onlar, ikiz olmalarına rağmen, çok sayıda ortak ilgileri yok.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1032434
#
# O, bu günlerde onunla arasına mesafe koyuyor.
# - bu gün... -> bugün...
# - http://tatoeba.org/eng/sentences/show/1034172
#
# Ben onlara düğün günlerinin ne zaman olduğunu sormak istiyorum.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1034617
#
# Onların ilişkisi hakkında bir şey bilmiyorum.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1034622
#
# Onların sorunlarıyla ilgili yapacak bir şeyim yok.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1034625
#
# Onların planı hakkında şey bilmiyorum.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1034627
#
# Onların testi geçeceğinden eminim.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1034628
#
# Onların evliliklerinden haberin olmamasına şaşırdım.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1034631
#
# Onların isimlerini hatırlayamadım.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1034633
#
# Biz otobüs terminalinde kazara onlarla karşılaştık.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1034635
#
# Ben, bu tartışmada onların yanında yer aldım.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1035060
#
# Onların hepsi aynı.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1035965
#
# Onların hepsinin, kolları, bacakları, ve kafaları var,onlar yürürler ve konuşurlar, ama şimdi onlara farklı yapmak isteyen bir şey var.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1035977
#
# Onların hiçbirinden hoşlanmıyorum.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1035987
#
# Onların hepsi asabi.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1035997
#
# Onların hepsi onun şarkısı tarafından büyülendi.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1036022
#
# Herkes bana bu günlerde Tony dedi.
# - bu gün... -> bugün...
# - http://tatoeba.org/eng/sentences/show/1036024
#
# Sen samimi olmalısın, onlar sana bir arkadaş gibi davranırlar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1036143
#
# Onlar müslümanlara hiçbir müslümanın kâfire karşı davranmadığı şekilde davranıyorlar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1036192
#
# Onlar müslümanlara karşı bir müslümanın düşmanına karşı asla davranmadığı şekilde davranıyor.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1036195
#
# Onlardan hiçbirinin kaza geçirmediğini umuyorum.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1037029
#
# Onların arabalarında "önce Irak sonra Fransa" diye okunan çıkartmalar vardı.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1037036
#
# Onlar yarına kadar işi yaptırmamda ısrar ettiler.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1037047
#
# Cümleler kelimelere içerik getirir. Cümlelerin kişilikleri vardır. Onlar komik, akıllı, aptal, anlayışlı, dokunaklı, incitici olabilirler.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1037335
#
# Ama bu cümleleri nerede buluruz? Ve onları nasıl çeviririz?
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1037372
#
# Biz her dilin tüm benzersizliğini yakalamak istiyoruz. Ve biz zaman içinde onların evrimini de yakalamak istiyoruz.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1037390
#
# Bu, onları bir ders kitabı için, bir uygulama için, bir araştırma projesi için, her şey için yeniden serbestçe kullanabileceğin anlamına gelir.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1037397
#
# Tanrıların tüm niteliklerinden acınacak bulduğum, onların intihar etme yeteneksizlikleridir.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1037409
#
# O şirketin yeni bilgisayar mimarisi ile ilgili bir sorun vardı. Onlar şimdi bir iptal çılgınlığını gözden geçirecekler.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1037615
#
# Tom ve arkadaşları onlarla gelmemi rica etti.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1037809
#
# Onlar kişinin mütevazı ya da tembel olduğunu düşünürdü.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1037837
#
# Bu günlerden biri bu günlerden hiçbiri değil.
# - bu gün... -> bugün...
# - http://tatoeba.org/eng/sentences/show/1037975
#
# Onlar hızla evlerini terk ettiler.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1038350
#
# Onlar gereksiz şeyleri attılar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1040076
#
# Onlar şikâyet etmekten başka bir şey yapmıyorlar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1040077
#
# Onlar karı kocaymış gibi davranıyorlar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1040079
#
# Onlar karı koca oldu.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1040082
#
# Onların okuyamaması veya hiç yazmaması anlamında onlar cahil değiller.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1040087
#
# Onlar, babamın halini hatırını sordular.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1040089
#
# Onlar, babalarının ölümünün yasını tuttular.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1040090
#
# Onlar sahnede sırayla şarkı söylediler.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1040092
#
# Onlar odayı boş buldular.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1040093
#
# Onlar, odanın çok sıcak olmasından şikayetçi oldular.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1040096
#
# Onlar, odada biraz uyudular.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1040097
#
# Onlar peş peşe odadan çıktılar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1040099
#
# Onlar rüzgar ve havanın elinde, denizde kayboldular.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1040100
#
# Onlar intikam için komşularının evini ateşe verdi.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1040101
#
# Onlar deprem için güvenli bir bina inşa etti.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1040325
#
# Onlar aşklarını gizli tuttular.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1040343
#
# Elbiselerim ıslandı bu yüzden onları çıkardım.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1040423
#
# İki eski âşık arkadaş kalabiliyorsa, ya onlar hâlâ aşıktır ya da hiç olmadılar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1040754
#
# Onlar dövüşmeyeceklerini söylediler.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1041013
#
# Onlar tamamen şaşırdılar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1041014
#
# Onlar İspanyolca konuşmuyorlardı.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1041016
#
# Gerçek onlara söyleniliyormuydu?
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1041018
#
# O, onlar onu erteliyordu dedi.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1041019
#
# Onların eldivenleri çift değil.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1041712
#
# Bulaşıkları temizledikten sonra, ben onları durularım.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1041774
#
# Kaza onları mutluluklarından mahrum etti.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1041993
#
# Onlar konuyu araştırıyorlar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1042117
#
# Onları affet, zira onlar ne yaptıklarını bilmiyorlar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1042668
#
# Adaya ulaşmak onlar için zordu.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1043045
#
# Onlarla görülmekten utanmam.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1043920
#
# Çocuklara sessiz olmalarını söyledim, fakat onlar gürültülü olmaya devam ettiler.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1045627
#
# Onlar bana ödeme yaparsa, onu yaparım.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1046299
#
# Onlarla müzakere yapması için onu atadık.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1046776
#
# Biz onların taleplerine boyun eğmemeliyiz.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1046800
#
# Onların ricasına boyun eğmek zorunda kaldık.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1046801
#
# Biz onların dükkanının bir başarısızlık olduğunu düşündük, fakat şimdi, zor günleri atlattılar ve hatta büyüdüler.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1046802
#
# Biz onlara moral desteği vereceğiz.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1046804
#
# Biz onlara para ve giysi sağladık.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1046805
#
# Köpeklere gelince, müşteriler onları bu mağazaya getiremiyebilirler.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1047440
#
# Büyük anlaşmazlıklara karşı zorlu bir mücadeleden sonra, onlar nihayet şirketi tekrar kendi ayakları üzerinde durdurdular.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1048058
#
# Onlar seninle alay ediyor.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1048111
#
# Onlar genellikle kırmızı ışıklarda parmaklarını şakırdatırlar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1048114
#
# O bavul onlarınki değil.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1048167
#
# Git ve onlara yardımcı ol, Bud.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1048468
#
# Onları çok uzun bekletmemelisin.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1048670
#
# Sadece onları toparlamanız gerekli.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1048720
#
# Onlardan herhangi birini seçebilirsiniz.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1048722
#
# Onlar beşte dükkânı kapattı.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1049490
#
# Onlar beşer kişilik gruplar oluşturdular.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1049491
#
# Onlar altı ay önce evlendi.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1049493
#
# Onlar, altı fit yüksekliğinde bir duvara tırmanmak zorunda kaldı.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1049502
#
# Onlar haziran ayında evlenecekler.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1049503
#
# Onlar altıda varırlar ve sonra hep birlikte akşam yemeği yeriz.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1049504
#
# Onlar yedide burada buluşacaklardı.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1049505
#
# Çiçekler o kadar narin ve güzeldir ki şiirler ve metaforlar olmadan onlar hakkında konuşamazsın.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1050959
#
# Barack Obama, nükleer silahlarla ilgili uluslararası bir yasaklamayı hedefliyor, fakat tüm savaşlarda onlara karşı değil.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1051032
#
# Onlar şehir hayatına can atıyorlar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1051091
#
# Onlar tehlikede olduğunda, kaçarlar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1051274
#
# Tom'un onlara kızma nedenini biliyorum.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1052323
#
# O sevimli bebek onların aşkının meyvesidir.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1052596
#
# Onlar siyasi sığınma aldıktan sonra vatandaş oldu.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1052856
#
# Biz beyzbolda onları yendik.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1053089
#
# Babamın küçük kütüphanesi çoğu polemik tanrılığı içeren kitaplardan oluşuyordu, onların çoğunu okudum. esas oluşuyordu.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1054773
#
# Iyi şans sayesinde onlar kaçtı.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1054891
#
# Onlar henüz burada değil.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1055354
#
# Onlar altın kadar iyi.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1055950
#
# Onlar kilisenin çocukları.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1055973
#
# Açık söylemek gerekirse, bu takımın kazanamayacak olmasının sebebi onları geride tutmanızdır.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1056685
#
# Onlar Japon sumo güreşçileridir.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1057734
#
# Onların arabayı çaldı dedikleri adam budur.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1058331
#
# Müzik için yetenek onların kanında akar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1058763
#
# Onlar müzik eşliğinde dans ediyorlardı.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1058772
#
# Çoğu kalelerin onları çevreleyen bir hendeği vardır.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1059298
#
# Onlar tuhaf bir keşif yaptı.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1060021
#
# Onlar barış yapmak için geldi.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1060049
#
# Onlar barış istemek için geldi.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1060050
#
# Onlar aramızda!
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1060196
#
# Kusura bakmayın ama, onların her ikisinin mantıklı amaçları var.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1060233
#
# Şu ana kadar yiyeceğin en iyi salata onların özel öğle yemeğiyle verdikleridir.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1060348
#
# Son gelişmeler onların seyahat planlarını değiştirmelerine neden oldu.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1061706
#
# Onlar bu fabrikada TV setleri üretiyorlar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1061818
#
# Benim için sürpriz oldu, onlar eti çiğ yediler.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1061934
#
# Yirmi kişiyi partime davet ettim fakat onların hepsi gelmedi.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1062221
#
# Onlar onun bir haftadır yatakta hasta olduğunu söylüyorlar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1062642
#
# Onların çevre üzerinde herhangi bir etkisi yok.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1062824
#
# Onlardan kaç tanesinin yardıma ihtiyacı olduğunu bilmiyordum.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1063599
#
# Ekvatora yakın dar bir bölgede bulunan,tropik yağmur ormanları o kadar hızlı yok oluyorlar ki 2000 yılına kadar onların yüzde sekseni gitmiş olabilir.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1063753
#
# Sigaraları azaltmaktansa, bayım, niçin onları bırakmıyorsun.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1063958
#
# Bayan tezgahtar bana bir sürü kravat gösterdi, ama ben onlardan herhangi birini beğenmedim.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1066106
#
# Oğlum yüksek okula girdi.
# - yüksek okul... -> yüksekokul...
# - http://tatoeba.org/eng/sentences/show/1066321
#
# O, onları seviyor.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1066372
#
# Maury Povich'e gelen insanlar genellikle sevgililerinin onları aldattıkları ile ilgili önemli iddialarda bulunmaktadırlar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1067294
#
# Oda arkadaşım, filmlere para harcama söz konusu olduğunda, müsriftir; o fiyatı ne olursa olsun, onları piyasaya çıktığı gün alıyor.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1067302
#
# Onlar üniversiteden mezun oldular.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1067349
#
# İlk başta, onların hepsi onun masum olduğuna ikna oldular.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1067373
#
# Onların hepsi iyi, bu yüzden üç kitap seçin.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1067384
#
# İki polis bir hırsız tutukladı. Onlar onu Bayan Miller'in evine gizlice girerken yakaladı.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1067471
#
# Onların her ikisi de çok heyecanlı.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1067486
#
# Bir insanın hayatında beş trajedi vardır. Ne yazık ki, onların hangileri olduğunu bilmiyorum.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1067684
#
# Tarihçinin rolü daha az keşfetmek ve onları çevirmek ve açıklamak yerine belgelerin kataloğunu hazırlamaktır.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1067930
#
# Tren geç vardığı için onlar programını değiştirmek zorunda kaldılar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1067984
#
# Sen benim genç kızımın oğlun ile aynı yaşta olduğunu biliyorsun.Onların nişanlanmalarına karar vermemin nedeni budur.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1068010
#
# Onlar metni tercüme ettiler.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1068035
#
# Ben, onlardan herhangi birini sevmiyorum.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1068815
#
# Hava güzel olursa, onlar mantar toplamak için ormana gidecek.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1069010
#
# Onlar Dan'ı görüyorlar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1069165
#
# Onları tanıyan tek kişi benim.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1069825
#
# Yanan arabalar, ölen insanlar vardı ve kimse onlara yardımcı olamadı.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1070265
#
# Onlar şiddetli düşmanlar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1070924
#
# O stajyerlere talimatları verdi fakat onlar talimatlarla ilgili karar veremediler.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1071166
#
# Onların her ikisi de evcil hayvan mağazasında çalışıyor.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1072878
#
# Onların cesur fikirleri olmalı.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1072879
#
# Onlar da başkalarına adil olmalıdır.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1072884
#
# Onlar birbirini çok iyi tanımıyorlar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1073319
#
# Onların ne düşündüğünü sormayın. Ne yaptığını sorun.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1073734
#
# Onların cihazı son derece gelişmiş.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1073916
#
# O onlardan daha zeki.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1073920
#
# Onlar bizi sıcak bir şekilde karşıladı.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1073928
#
# Güneşin batarken, onlar işlerini bıraktılar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1075794
#
# Güneş batarken, onlar hâlâ dans ediyorlardı.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1075797
#
# Onların yaptığı model uçak kırılgandı.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1076001
#
# Yağmur durduğu için onlar oyuna devam ettiler.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1076120
#
# Televizyon izleyicileri eğlendirmesinin yanı sıra onları aydınlatır.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1077802
#
# O, bu günlerde yaptığı araştırmayı ihmal ediyor.
# - bu gün... -> bugün...
# - http://tatoeba.org/eng/sentences/show/1077835
#
# Düşman kasabaya ulaşmadan önce, onların ilerlemesini durdurun.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1078155
#
# Kitaplar o kadar değerliydi ki onlara büyük bir titizlikle bakıldı.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1079375
#
# Belgelerin yığınını eşit şekilde böl, ve onları birer birer odanın her iki tarafına koy.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1079377
#
# Onlar şu anda bir mola veriyorlar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1079639
#
# Onlar nasıl ünlü oldular?
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1079755
#
# Onlar boşanalı zaten iki yıl oldu.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1080314
#
# İmparatora gelince, o dünyanın hükümdarıdır. Barbarlara gelince, onlar dünyanın uşaklarıdır.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1080325
#
# Papazın vaazları seni sıkabilir fakat onlar ahlaken iyi örnektir.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1080481
#
# Onlar hayal kırıklığına uğradılar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1080563
#
# Yiyecek yokluğu onları çok acıktırdı.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1082374
#
# Eğer doğru olarak hatırlıyorsam, onlar kuzenler.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1084410
#
# Birçok Avrupa mutfakları orada kuru malzemeler tartıldığından dolayı bir teraziye sahiptir, Amerika'da tam tersine onlar hacimle ölçülmektedir.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1085444
#
# Oluklu kaşıklar geleneksel pelin ayininde belirli bir role sahiptir.Onlar bir adet küp şekeri soğuk suyla bardaklarının içine eritmek için küp şekeri bardağın üstünde tutmak için kullanılır.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1085532
#
# Onlar parkta oynuyor olabilirler.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1086982
#
# Onlar parkta bir bankta oturdu.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1086983
#
# Onlar parkın yakınında yeni bir evde yaşıyor.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1086984
#
# Onlar parkta koşuyorlar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1086985
#
# Onlar, caddenin karşısındaki yeni komşuları ile arkadaş oldular.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1086986
#
# Onlar yüz yüze durdu.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1086987
#
# Onlar iyi bir fırsat kaçırdı.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1086988
#
# Onlar fabrikalarda çalıştılar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1086989
#
# Onlar mutlu görünüyorlar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1086993
#
# Onlar hem zenginlerdi hem de mutlulardı.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1086994
#
# Onlar mutlular.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1086995
#
# Onlar mutlu bir hayat yaşadılar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1086996
#
# Onlar mutlu olmalılar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1086997
#
# Onlar mutluluğun peşindeler.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1086998
#
# Onlar mutluluğu aramaya gittiler.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1086999
#
# Onlar Hiroşima'ya bir atom bombası attılar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1087000
#
# Onlar sadece protestoyu görmezden gelmediler, aynı zamanda basına yalan söylediler.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1087001
#
# Onlar saldırılara karşı bağışıktır.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1087002
#
# Onlar üç mil öteye yürüdü.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1087003
#
# Onlar yeni bir okul binası inşa etmek için bir proje oluşturdu.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1087004
#
# Onların sunduğu planı gerçekten anlamıyorum.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1087304
#
# Onlara ihtiyacı olmasa bile kitapları ona iade edeceğim.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1087388
#
# Onlar bizim bu günlerden birinde bir deprem yaşayacağımızı söylüyorlar.
# - bu gün... -> bugün...
# - http://tatoeba.org/eng/sentences/show/1087563
#
# Onlar bizim bu günlerden birinde bir deprem yaşayacağımızı söylüyorlar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1087563
#
# Bu günlerden birinde niçin evime gelmiyorsun?
# - bu gün... -> bugün...
# - http://tatoeba.org/eng/sentences/show/1087570
#
# Onlar tuşları aşağı yukarı hareket ettirdiler.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1087719
#
# Onlar her zamanki gibi geç kaldılar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1088605
#
# Benim elmalarımı al, çocuk, ve onları şehirde sat.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1088660
#
# Onlar asla birbirlerini tekrar görmeyeceklerdi.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1088892
#
# Onlar eski binayı iki gün içinde yıkacaklar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1088896
#
# Onlar iki yıl önce buraya taşındı.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1088899
#
# Onlar otuz dakika sonra bize yetiştiler.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1088905
#
# Onlar üçte burada olacaklar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1088910
#
# Onlar yol boyunca üçü yan yana yürüdü.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1088916
#
# Onlar üç gün içinde gidiyorlar. Yani 10 Haziran'da.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1088921
#
# Onlar üç yıl önce buraya taşındılar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1088922
#
# Onlar arkaya arkaya üç yıl Japonya Kupasını kazandılar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1088923
#
# Onlar her dört yılda bir büyük yarışmaların olması gerektiğine inanıyorlardı.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1088924
#
# Onlar yaklaşık beş yüz yıl önce Peru'da imparatorluklarını kurdular.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1088928
#
# Onlar bir Mayıs itibarıyla sonuçları açıkladılar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1088931
#
# Onlar seksen millik yolculuğu tamamladılar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1088934
#
# Onlar şu anda İngiltere'de büyük bir şirket için çalışıyorlar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1089313
#
# Bakın! Onlar evden ayrılıyorlar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1089314
#
# Onlar üç binden fazla denizciyi öldürdü
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1090147
#
# Onlar onu güçlü bir erkeğin cesur hareketi olarak gördüler.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1090148
#
# Onların Kanada'ya geçmeleri için izin verilmedi.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1090149
#
# 1847 yılında, onlar kendilerini bağımsız ilan ettiler.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1090151
#
# Onlar birbirlerini aptal göstermeye çalıştılar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1090152
#
# Onlar diğer bir çiftçiyi ve oğlunu da ele geçirdiler.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1090154
#
# Onlar kurşunu olduğu yerde bırakmaya karar verdiler.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1090155
#
# Onlar daha iyi çalışma koşulları talep etmedi.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1090156
#
# Onlar onun grup içinde en iyi yazar olduğunu söylediler.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1090159
#
# Onlar altın piyasasını kontrol altına almaya çalıştılar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1090160
#
# Onlar mümkün olduğu kadar çok sayıda insan yakalardı.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1090162
#
# Onlar yaşam için yeni yollar denemek istediler.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1090163
#
# Onlar ısıtma sistemini onarmak için buradalar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1090166
#
# O okulda. Onlar da mı?
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1090439
#
# Onlar geçen temmuzda tatildeydiler.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1090502
#
# Onlar dün sınıfta değildi.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1090520
#
# Onlar parkta her öğleden sonra top oynarlar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1090565
#
# Amerika'daki kilise okullarının ve bazı özel okulların üniforması vardır, onlar yaygın değildir.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1091795
#
# Amerika Birleşik Devletlerinde, geçtiğimiz yirmi yıl boyunca 20 milyon yeni iş yaratılmıştır, onların çoğu hizmet sektöründedir.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1091800
#
# ABD'de, onlardan bilgi almak için insanlara işkence yapmak yasaktır.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1091988
#
# Onlar kapıya doğru yürüdü.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1091998
#
# Onlar sözde savaş mağdurlarıdır.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1096789
#
# Onlar Hindistanlı bir kıza ve İtalyalı bir oğlana bakıyorlardı.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1096793
#
# Onlar ona votka katılmış bir bardak portakal suyu verdiler.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1096794
#
# Onlar benim BMW'yi tahrip ettiler.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1096866
#
# Onlar kasabadaki Ceilidh'e gitmiyorlar mı?
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1096955
#
# Mary bir gün bir prensle karşılaşacağını ve onların evleneceklerini hayal etti.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1097077
#
# Onlar orada yaşıyor.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1097353
#
# Onların sadece küçük bir kızı vardı.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1097371
#
# Yanında iki kutu bedava ayakkabı cilası ile birlikte onlar sadece 50 dolar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1097379
#
# Dikkatli olun anne, onlar size doğru geliyor.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1097445
#
# Onların hepsi zararsız çocuklar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1097501
#
# John bu günlerde endişesiz.
# - bu gün... -> bugün...
# - http://tatoeba.org/eng/sentences/show/1101142
#
# John bu günlerde çok içiyor. Biz onu artık içmemesi için durdurmak zorundayız.
# - bu gün... -> bugün...
# - http://tatoeba.org/eng/sentences/show/1101145
#
# Onun sonunda konuşma sanatı ve mantık ile ilgili , Socrates metodunda herhangi bir anlaşmazlık örneği ile biten ikincisinin sonunda iki küçük skeç vardı.
# - metod... -> metot...
# - http://tatoeba.org/eng/sentences/show/1103919
#
# Onun yararına onlara yardımcı olduğu kesindir.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1104483
#
# O, işsiz olduğu için, onların evliliği başarısız oldu.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1104500
#
# Ben sonradan bana R. Burton 'ın Tarihi Koleksiyonlarını satın almamı sağlaması için onları sattım.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1104692
#
# Onlar orada mutlu bir hayat yaşadı.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1105781
#
# Onlar orada kullanılanlara benzer aletler kullandılar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1105785
#
# Niçin onların şikâyet ettikleri sadece benim? Onlar sadece beni örnek veriyorlar ve beni bir günah keçisi olarak kullanıyorlar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/1105977
#
# Hiçbir insan onları bilemez, hiçbir avcı barut ve kurşunla onları vuramaz. - Düşünceler özgürdür!
# - onla... -> onunla...
# ...
# - http://tatoeba.org/eng/sentences/show/7765699
#
# Hemen söylemeliyim ki, bana bu yetkiyi onlar bilerek ve anlayarak vermediler.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/7768662
#
# Osmanlı Devleti'nin yanında, koskoca Almanya, Avusturya-Macaristan varken hepsini birden yenen, yerlere seren İtilâf kuvvetleri karşısında, yeniden onlarla düşmanlığa varabilecek durumlara girmekten daha büyük mantıksızlık ve akılsızlık olamazdı.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/7768718
#
# Türk ata yurduna ve Türk'ün bağımsızlığına saldıranlar kimler olursa olsun, onlara bütün ulusça silahlı olarak karşı çıkmak ve onlarla savaşmak gerekiyordu.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/7774937
#
# Böyle bir soru sormaktaki düşüncem, biraz da onları özendirmek ve uyarmak idi. Müfettişliğin verdiği son bilgi, bunun üzerinedir.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/7783369
#
# Onlar gelinceye değin, Edirne ili haklarının savunucusu olmak üzere, beni vekil ettiklerini belirten, imzalı bir belgeyi kendi imzanızla ve şifre ile bildiriniz.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/7783399
#
#
#
# ***
#
#
# ### Likely Error report for user [whitekite](https://tatoeba.org/eng/user/profile/whitekite).
#
#
# Tom Mary'e ne tür bir arabası olduğunu sordu.
# - mary'e... -> mary'ye...
# - http://tatoeba.org/eng/sentences/show/8988359
#
# Tom Mary'nin ona dik dik baktığını farketti.
# - farket... -> fark et...
# - http://tatoeba.org/eng/sentences/show/9020674
#
# Tom Mary'e kendisi için bir sandviç yapması gerektiğini söyledi.
# - mary'e... -> mary'ye...
# - http://tatoeba.org/eng/sentences/show/9020685
#
#
#
# ***
#
#
# ### Likely Error report for user [Jum](https://tatoeba.org/eng/user/profile/Jum).
#
#
# Hellowine ýakynlaşýarys we bu gün Hellowin hakynda seniň bilen gürleşip biljegimi pikir etdim.
# - bu gün... -> bugün...
# - http://tatoeba.org/eng/sentences/show/7931713
#
#
#
# ***
#
#
# ### Likely Error report for user [Turkish_Bible](https://tatoeba.org/eng/user/profile/Turkish_Bible).
#
#
# Yeryüzünü aydınlatmak, gündüze ve geceye egemen olmak, ışığı karanlıktan ayırmak için onları gökkubbeye yerleştirdi. Tanrı bunun iyi olduğunu gördü.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/7931741
#
# Tanrı, "Verimli olun, çoğalın, denizleri doldurun, yeryüzünde kuşlar çoğalsın" diyerek onları kutsadı.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/7931745
#
# Onları kutsadı ve, "Verimli olun, çoğalın" dedi, "Yeryüzünü doldurun ve denetiminize alın; denizdeki balıklara, gökteki kuşlara, yeryüzünde yaşayan bütün canlılara egemen olun.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/7931752
#
# RAB Tanrı yerdeki hayvanların, gökteki kuşların, hepsini topraktan yaratmıştı. Onlara ne ad vereceğini görmek için hepsini Adem'e getirdi. Adem her birine ne ad verdiyse, o canlı o adla anıldı.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/7935014
#
# RAB Tanrı Adem'le karısı için deriden giysiler yaptı, onları giydirdi.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/7939303
#
# Onları erkek ve dişi olarak yarattı ve kutsadı. Yaratıldıkları gün onlara "İnsan" adını verdi.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/7964014
#
# "Yarattığım insanları, hayvanları, sürüngenleri, kuşları yeryüzünden silip atacağım" dedi, "Çünkü onları yarattığıma pişman oldum."
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/7965693
#
# Tanrı yeryüzüne baktı ve her şeyin ne denli bozulduğunu gördü. Çünkü insanlar yoldan çıkmıştı. Tanrı Nuh'a, "İnsanlığa son vereceğim" dedi, "Çünkü onların yüzünden yeryüzü zorbalık doldu. Onlarla birlikte yeryüzünü de yok edeceğim."
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/7965700
#
# Yanına hem kendin, hem onlar için yenebilecek ne varsa al, ileride yemek üzere depola.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/7965718
#
# Onlarla birlikte her tür hayvan - evcil hayvanların, sürüngenlerin, kuşlarla uçan yaratıkların her türü - gemiye bindi. Soluk alan her tür canlı çifter çifter Nuh'un yanına gelip gemiye bindi.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/7968252
#
# Nuh'un üç oğlu bunlardı. Yeryüzüne yayılan bütün insanlar onlardan türedi.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/7994414
#
#
#
# ***
#
#
# ### Likely Error report for user [Ivanovb](https://tatoeba.org/eng/user/profile/Ivanovb).
#
#
# Danyal peygamber kitabında Baba ve Oğul hakkında şöyle buyruluyor: "Bir taş insan eli değmeden kesilip heykelin demirden, kilden ayaklarına çarparak onları paramparça etti. Demir, kil, tunç, gümüş, altın aynı anda parçalandı; yazın harman yerindeki saman çöpleri gibi oldular. Derken bir rüzgar çıktı, hiç iz bırakmadan hepsini alıp götürdü. Heykele çarpan taşsa büyük bir dağ oldu, bütün dünyayı doldurdu."
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/8067678
#
# O gün birçokları bana diyecek ki, ‘Ya Rab, ya Rab! Biz senin adınla peygamberlik etmedik mi? Senin adınla cinler kovmadık mı? Senin adınla birçok mucize yapmadık mı?’ O zaman ben de onlara açıkça, ‘Sizi hiç tanımadım, uzak durun benden, ey kötülük yapanlar!’ diyeceğim.”
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/8080095
#
# Elişa, “Korkma, çünkü bizim yandaşlarımız onlarınkinden daha çok” diye karşılık verdi.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/8080689
#
# Deliceler nasıl toplanıp yakılırsa, çağın sonunda da böyle olacaktır. İnsanoğlu meleklerini gönderecek, onlar da insanları günaha düşüren her şeyi, kötülük yapan herkesi O'nun egemenliğinden toplayıp kızgın fırına atacaklar. Orada ağlayış ve diş gıcırtısı olacaktır. Doğru kişiler o zaman Babaları'nın egemenliğinde güneş gibi parlayacaklar. Kulağı olan işitsin!
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/8099107
#
# İsa on iki öğrencisini yanına çağırıp onlara kötü ruhlar üzerinde yetki verdi. Böylece kötü ruhları kovacak, her hastalığı, her illeti iyileştireceklerdi.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/8107021
#
# Bu nedenle gidin, bütün ulusları öğrencilerim olarak yetiştirin; onları Baba, Oğul ve Kutsal Ruh'un adıyla vaftiz edin.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/8146701
#
# İsa onlara şöyle buyurdu: “Dünyanın her yanına gidin, Müjde'yi bütün yaratılışa duyurun.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/8146708
#
# Bizler gibi Kutsal Ruh'u alan bu insanların vaftiz edilmesini önlemek için kim onları sudan geri çevirebilir?
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/8146869
#
# Onlara şu yolda buyruk verdi: "Dünyanın dört bucağına gidin ve Sevinç Getirici Haber'i herkese yayın.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/8146877
#
# Gidin bütün ulusları öğrencim yapın. Onları Baba, Oğul ve Kutsal Ruh adıyla vaftiz edin.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/8146883
#
# Kardeşlerime git ve onlara söyle, benim Babam'ın ve sizin Babanız'ın, benim Tanrım'ın ve sizin Tanrınız'ın yanına çıkıyorum.”
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/8188493
#
#
#
# ***
#
#
# ### Likely Error report for user [Oldboy](https://tatoeba.org/eng/user/profile/Oldboy).
#
#
# Malesef, cevap basit değil.
# - malesef... -> maalesef...
# - http://tatoeba.org/eng/sentences/show/8468916
#
#
#
# ***
#
#
# ### Likely Error report for user [nedim](https://tatoeba.org/eng/user/profile/nedim).
#
#
# Onların hepsi palyaço gibi giyinmişlerdi.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/8438995
#
# Ne derlerse desinler halen haftaya Avusturalya'ya gitmeyi planlıyorum.
# - avusturalya... -> avustralya...
# - http://tatoeba.org/eng/sentences/show/8609605
#
# Burası Tom ve Mary'nin bize onlarla buluşmak için söylediği yer.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/8789750
#
# Onları etkilemeye çalışıyoruz.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/8791635
#
#
#
# ***
#
#
# ### Likely Error report for user [Cumle_Kurucu](https://tatoeba.org/eng/user/profile/Cumle_Kurucu).
#
#
# Romanı onlara tavsiye etti.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/8451260
#
# Onlar iyi arkadaş.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/8461432
#
# Onlara kızma sebebini biliyorum.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/8473741
#
# Ne istediğine dair onlara genel bir çerçeve çizdi.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/8488160
#
# Bana komik bir mesaj atmış.
# - atmış... -> altmış... (çoğu false positive)
# - http://tatoeba.org/eng/sentences/show/8490727
#
# Onlardan yardım isteyebilirsin.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/8517998
#
# Bana onların adresini verir misin?
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/8518013
#
# Onları en son ne zaman gördün?
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/8518066
#
# Bu yıl ona bir doğumgünü kartı gönderelim.
# - doğumgünü... -> doğum günü...
# - http://tatoeba.org/eng/sentences/show/8533035
#
# Onlara ne söyledi?
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/8539218
#
# Onlara ne demiş?
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/8539222
#
# Onların yardımına ihtiyacım var.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/8544498
#
# Bu haftasonunu ömrü boyunca hatırlayacak.
# - haftasonu... -> hafta sonu...
# - http://tatoeba.org/eng/sentences/show/8544527
#
# Onlara aslında güvenemediğini söyledi bana.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/8554765
#
# Evde hiç bira içmez.
# - hiç bir... -> hiçbir...
# - http://tatoeba.org/eng/sentences/show/8579528
#
#
#
# ***
#
#
# ### Likely Error report for user [cartals](https://tatoeba.org/eng/user/profile/cartals).
#
#
# Umarım iyi bir haftasonu geçirirsin.
# - haftasonu... -> hafta sonu...
# - http://tatoeba.org/eng/sentences/show/8456892
#
# Yapabildiğim herhangi bir zaman Avusturalya'ya gitmeye çalışıyorum.
# - avusturalya... -> avustralya...
# - http://tatoeba.org/eng/sentences/show/8457888
#
# Sami Layla'yı öpüyorken, Layla'nın pantalonunu çıkarmaya başladı.
# - pantalon... -> pantolon...
# - http://tatoeba.org/eng/sentences/show/8457908
#
# Tom'un Avusturalya'da olduğunu mu düşünüyorsun ?
# - avusturalya... -> avustralya...
# - http://tatoeba.org/eng/sentences/show/8459546
#
# Kimse farketmeden eve gizlice girdi ve hemen yatağa girdi.
# - farket... -> fark et...
# - http://tatoeba.org/eng/sentences/show/8460411
#
#
#
# ***
#
#
# ### Likely Error report for user [keremcik](https://tatoeba.org/eng/user/profile/keremcik).
#
#
# Allah bu sabah kaybettiğimiz Amerikalıları kutsasın. Ailelerini yatıştırsın. Allah bu sevdalısı olduğumuz ülkeye gözkulak olsun. Amin.
# - gözkulak... -> göz kulak...
# - http://tatoeba.org/eng/sentences/show/8494900
#
#
#
# ***
#
#
# ### Likely Error report for user [tahtabiti](https://tatoeba.org/eng/user/profile/tahtabiti).
#
#
# Onsekizinci yüzyılda yaşamış kölelerin trajik kaderinden bahsediyor.
# - onsekiz... -> on sekiz...
# - http://tatoeba.org/eng/sentences/show/8638824
#
#
#
# ***
#
#
# ### Likely Error report for user [ondal30](https://tatoeba.org/eng/user/profile/ondal30).
#
#
# Bir insanın gök kuşağını yedi renkle sınırlaması, gök kuşağını tanımamasındandır.
# - gök kuşağı... -> gökkuşağı...
# - http://tatoeba.org/eng/sentences/show/8647678
#
# Tom'un köpeği Mary'in kedisini korkuttu.
# - mary'i... -> mary'yi...
# - http://tatoeba.org/eng/sentences/show/8825789
#
# Bu günlerde sosyal mesafe önemli.
# - bu gün... -> bugün...
# - http://tatoeba.org/eng/sentences/show/8834531
#
#
#
# ***
#
#
# ### Likely Error report for user [rimzone](https://tatoeba.org/eng/user/profile/rimzone).
#
#
# Vejetaryen beslenmek sadece eti terketmek anlamına gelmez.
# - terket... -> terk et...
# - http://tatoeba.org/eng/sentences/show/8754281
#
#
#
# ***
#
#
# ### Likely Error report for user [hamit](https://tatoeba.org/eng/user/profile/hamit).
#
#
# Onlar çaresiz.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/8796940
#
#
#
# ***
#
#
# ### Likely Error report for user [jungnet](https://tatoeba.org/eng/user/profile/jungnet).
#
#
# Onlar Fransızca öğrenmek istediklerini söylediler.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/8871039
#
# Rastgelelik arama motorunda aradığım herşeyi bulabiliyorum.
# - herşey... -> her şey...
# - http://tatoeba.org/eng/sentences/show/8871066
#
#
#
# ***
#
#
# ### Likely Error report for user [codex360](https://tatoeba.org/eng/user/profile/codex360).
#
#
# Onlar çok iyi anlaşıyorlar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/8897502
#
#
#
# ***
#
#
# ### Likely Error report for user [cagri](https://tatoeba.org/eng/user/profile/cagri).
#
#
# Burada ihtiyacım olan herşey var.
# - herşey... -> her şey...
# - http://tatoeba.org/eng/sentences/show/8904790
#
# Onlar köpekten korkuyor.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/8956325
#
# Onlar köpekten korkarlar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/8956327
#
# Onlar köpeklerden korkarlar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/8956328
#
#
#
# ***
#
#
# ### Likely Error report for user [faruk](https://tatoeba.org/eng/user/profile/faruk).
#
#
# Onlar penceredir.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/8946503
#
# Sen burada hiç bir şey bulmayacaksın.
# - hiç bir... -> hiçbir...
# - http://tatoeba.org/eng/sentences/show/8946527
#
# Onlar buna inanır.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/8946528
#
# Onlar özgürdür.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/8957331
#
# Onları herkes istiyor.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/8957333
#
# Onlar hekim.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/8981670
#
#
#
# ***
#
#
# ### Likely Error report for user [unixd](https://tatoeba.org/eng/user/profile/unixd).
#
#
# Onlar meyveyi seviyorlar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/9081969
#
#
#
# ***
#
#
# ### Likely Error report for user [mxtxo](https://tatoeba.org/eng/user/profile/mxtxo).
#
#
# Onlar hâlâ beraberdiler.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/9091635
#
# Tom ve Mary kapıyı kilitleyemediler çünkü onlarda yanlış anahtar vardı.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/9092024
#
# Onları nerede öğrendin?
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/9092040
#
# Tom ve Mary patronlarının neden onlardan Boston'a gitmelerini istediğini bilmiyorlar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/9099607
#
# Tom ve Mary bunu eğer John onlardan isterse yapacaklarını söylüyorlar.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/9111591
#
#
#
# ***
#
#
# ### Likely Error report for user [aydincan77](https://tatoeba.org/eng/user/profile/aydincan77).
#
#
# O beysbol takımında, değil mi?
# - beysbol... -> beyzbol...
# - http://tatoeba.org/eng/sentences/show/9094546
#
# Yanni imama herşeyi anlattı.
# - herşey... -> her şey...
# - http://tatoeba.org/eng/sentences/show/9094761
#
# Tom hiç bir zaman bu kadar çok gülmezdi.
# - hiç bir... -> hiçbir...
# - http://tatoeba.org/eng/sentences/show/9095197
#
#
#
# ***
#
#
# ### Likely Error report for user [tuubaersoy](https://tatoeba.org/eng/user/profile/tuubaersoy).
#
#
# Tom Mary'i tekrar görmek istedi.
# - mary'i... -> mary'yi...
# - http://tatoeba.org/eng/sentences/show/9181118
#
#
#
# ***
#
#
# ### Likely Error report for user [fahrettinonder](https://tatoeba.org/eng/user/profile/fahrettinonder).
#
#
# Onlar vazgeçeceklerini söyledi.
# - onla... -> onunla...
# - http://tatoeba.org/eng/sentences/show/9264566
#
# ***
# done

# %%
with open('/content/output.MD','w',encoding="utf8") as writefile: 
 writefile.write(output)
print("file written")
# Out:
# file written
