# %% [markdown]
# <a href="https://colab.research.google.com/github/increpare/tatoeba_toki_pona_spellcheck/blob/main/tatoeba_turkish_spellcheck.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
replacements = """
Hiç bir -> Hiçbir 
Farket -> Fark et 
Terket -> Terk et 
Umru -> Umuru 
Bir çok -> Birçok 
Afedersin -> Affedersin 
Döğüş -> Dövüş 
Aperatif -> Aperitif 
* Olağandışı -> Olağan dışı 
Gözardı -> Göz ardı 
* Hıristiyan -> Hristiyan 
Bir kaç -> Birkaç 
Buyrun -> Buyurun 
Mahçup -> Mahcup 
Eposta -> E-posta 
İki yüzlü -> İkiyüzlü 
Haftasonu -> Hafta sonu 
Akıl almaz -> Akılalmaz 
Allerji -> Alerji 
Mütevazi -> Mütevazı 
Proğram -> Program 
Fotograf -> Fotoğraf 
Marry -> Mary 
Nerde -> Nerede 
Taktir -> Takdir 
* Arabulucu -> Ara bulucu 
Göz yaşı -> Gözyaşı 
Sarfet -> Sarf et 
Makina -> Makine 
Malolmak -> Mal olmak 
Motorsiklet -> Motosiklet 
Belkide -> Belki de 
Traş -> Tıraş 
Haket -> Hak et 
Madem ki -> Mademki 
* Öğe -> Öge 
Tabi ki -> Tabii ki 
Banço -> Banjo 
Burda -> Burada 
Herşey -> Her şey 
Kolleksiyon -> Koleksiyon 
* ortaçağ -> Orta Çağ 
Acenta -> Acente 
İtibariyle -> İtibarıyla 
Orjinal -> Orijinal 
Entellektüel -> Entelektüel 
Hemde -> Hem de 
Kominist -> Komünist 
* Sualtı -> Su altı 
Antreman -> Antrenman 
Çeki düzen -> Çekidüzen 
Doğumgünü -> Doğum günü 
Gök kuşağı -> Gökkuşağı 
Gözkulak -> Göz kulak 
Kıral/Kıraliçe/Kıraliyet/Kırallık -> Kral/Kraliçe/Kraliyet/Krallık 
Alt üst -> Altüst 
Birsürü -> Bir sürü 
Bulüz -> Bluz 
Can kurtaran -> Cankurtaran 
İnsan oğlu -> İnsanoğlu 
Müdahele -> Müdahale 
Orta okul -> Ortaokul 
Yinede -> Yine de 
Açıkca -> Açıkça 
Filim -> Film 
Hiçte -> Hiç de 
Birden bire -> Birdenbire 
Döküman -> Doküman 
Vaz geç -> Vazgeç 
Fantazi -> Fantezi 
Farzet -> Farz et 
Neyseki -> Neyse ki 
Okur yazar -> Okuryazar 
Peşpeşe -> Peş peşe 
Ünvan -> Unvan 
Arasıra -> Ara sıra 
Başbaşa -> Baş başa 
Çoşku -> Coşku 
Deniz aşırı -> Denizaşırı 
Gözüpek -> Gözü pek 
Gurup -> Grup 
Herzaman -> Her zaman 
Koperatif -> Kooperatif 
Klüp -> Kulüp 
Orda -> Orada 
Oysa ki -> Oysaki 
Sivri sinek -> Sivrisinek 
Alış veriş -> Alışveriş 
Apandist -> Apandisit 
* Ayışığı -> Ay ışığı 
Başı boş -> Başıboş 
Dahada -> Daha da 
Gardrop -> Gardırop 
* Göz bebeği -> Gözbebeği 
Herkez -> Herkes 
Herne -> Her ne 
Hiçkimse -> Hiç kimse 
İstakoz -> Istakoz 
Kapşon -> Kapüşon 
Kaysı -> Kayısı 
Pantalon -> Pantolon 
Şöför -> Şoför 
Yanısıra -> Yanı sıra 
Ana okulu -> Anaokulu 
Ayırım -> Ayrım 
Değilmi -> Değil mi 
Düz taban -> Düztaban 
Heryer -> Her yer 
Israf -> İsraf 
İyiki -> İyi ki 
Kamu oyu -> Kamuoyu 
Menejer -> Menajer 
Meşkul -> Meşgul 
Müsade -> Müsaade 
Parlemento -> Parlamento 
Pilaj -> Plaj 
Raslantı -> Rastlantı 
Yanlız -> Yalnız 
Hakket -> Hak et
* Devekuşu -> Deve kuşu 
* Köpekbalığı -> Köpek balığı
Metod -> Metot
Her hangi -> Herhangi
Herzaman -> Her zaman
Heryer -> Her yer
Kılınç -> Kılıç
Atmış -> Altmış (çoğu false positive)
Onbir/Oniki/Onüç/Ondört/Onbeş/Onaltı/Onyedi/Onsekiz/Ondokuz -> On bir/On iki/On üç/On dört/On beş/On altı/On yedi/On sekiz/On dokuz
Pekçok -> Pek çok
Pekaz -> Pek az
Çokaz -> Çok az
İnsiyatif -> İnisiyatif 
Kareografi -> Koreografi
Malesef -> Maalesef
İlk okul -> İlkokul
Ana okulu -> Anaokulu
Matamatik -> Matematik
Müstehak -> Müstahak
Sohpet -> Sohbet
Süpriz -> Sürpriz
Tesbit -> Tespit
Ardarda -> Art arda
Birarada -> Bir arada
Elele -> El ele
Yanyana -> Yan yana
Eksoz -> Egzoz
Eylenmek/Eylence -> Eğlenmek/Eğlence
Hem fikir -> Hemfikir
Labaratuar/Labaratuvar -> Laboratuvar
Meyva -> Meyve
Nufus -> Nüfus
Sarmısak -> Sarımsak
Yinede -> Yine de
Yüz ölçüm -> Yüzölçüm
Kızkardeş -> Kız kardeş
Kızarkadaş -> Kız arkadaş
Haked... -> Hak ed...
Sarfed... -> Sarf ed...
Farked... -> Fark ed...
Terked... -> Terk ed...
Bu gün -> Bugün
Büyük anne -> Büyükanne
Büyük baba -> Büyükbaba
Yada -> Ya da
Klavuz -> Kılavuz
Farzed... -> Farz ed...
Çarşanba -> Çarşamba
Perşenbe -> Perşembe
İstambul -> İstanbul
Penbe -> Pembe
Fonksyon -> Fonksiyon
Rasgele -> Rastgele (sıfat-zarf) 
Rasgelmek -> Rast gelmek
Hergün -> Her gün
...pde -> ...pte
...pden -> ...pten
...pda -> ...pta
...pdan -> ...ptan
...fde -> ...fte
...fden -> ...ften
...fda -> ...fta
...fdan -> ...ftan
...sde -> ...ste
...sden -> ...sten
...sda -> ...sta
...sdan -> ...stan
...çda -> ...çta
...çdan -> ...çtan
...çde -> ...çte
...çden -> ...çten
...hda -> ...hta
...hdan -> ...htan
...hden -> ...hten
...kda -> ...kta
...kdan -> ...ktan
...şde -> ...şte
...şden -> ...şten
...kca -> ...kça
...kce -> ...kçe
...pca -> ...pça
...pce -> ...pçe
...çca -> ...çça
...çce -> ...ççe
...şca -> ...şça
...şce -> ...şçe
Zıttı -> Zıddı
Yüksek okul -> Yüksekokul
Hastahane -> Hastane
Eczahane -> Eczane
Pastahane -> Pastane
Postahane -> Postane
Senle -> Seninle
Benle -> Benimle
Onla -> Onunla
israr -> ısrar
Avusturalya -> Avustralya
Brazilya -> Brezilya
Ünüversite -> Üniversite
Beysbol -> Beyzbol
Cimnastik -> Jimnastik 
Hava limanı -> Havalimanı
Hava alanı -> Havaalanı
Gök yüzü -> Gökyüzü
Ampül -> Ampul
Aktrist -> Aktris
Mary'i -> Mary'yi (Telaffuza göre görüş farkı olabilir)
Mary'e -> Mary'ye (Telaffuza göre görüş farkı olabilir)
Mary'le -> Mary'yle (Telaffuza göre görüş farkı olabilir)
Aç gözlü -> Açgözlü
"""

# %%
import re

change_lines = replacements.split("\n")

change_lines = [ line.strip() for line in change_lines if not len(line.strip())==0]

#filtering out asterisks "We have two Turkish language associations and they have differences of opinion about spelling of some words and that word is one of them. I put an asterisk at the beginning of them to indicate that. I now replaced them with ※ to avoid confusion."
replacements_noasterisk = [ line for line in change_lines if not "*" in line ]



replacements_simple = [ line for line in replacements_noasterisk if (not "/" in line) and (not "..." in line)]
replacements_multi = [ line for line in replacements_noasterisk if ("/" in line)]

regex_start = re.compile(r"\b\.\.\.\B")
replacements_regex_start = [ line for line in replacements_noasterisk if bool(regex_start.search(line))]

regex_end = re.compile(r"\B\.\.\.\b")
replacements_regex_end = [ line for line in replacements_noasterisk if bool(regex_end.search(line))]


def toLower_turkish(s):
  s = s.replace("I", "ı")
  s = s.replace("İ", "i")
  return s.lower()

def parseline(l):
  lr = l.split("->")
  src = toLower_turkish(lr[0].strip())
  dst = lr[1].strip()
  bracket_index = dst.find("(")  
  if bracket_index>=0:
    cleave = dst.split("(")
    dst = cleave[0].strip()
  return {"src":src,"dst":dst,"message":l}

change_lines = replacements.split("\n")

replacement_rules = []



# simple rules A -> B
for line in replacements_simple:
  parsed = parseline(line)
  regex = re.compile(r"\b"+parsed["src"]+r"\b")
  replacement_rules.append({
      "regex":regex,
      "change_from":parsed["src"],
      "change_to":parsed["dst"],
      "message":parsed["message"]
  }) 


#1 rules like "A/B -> C" or "A/B/C -> D/E/F"

for line in replacements_multi:
  parsed = parseline(line)
  change_from=parsed["src"]
  change_to=parsed["dst"]
  
  from_parts=change_from.split("/")
  to_parts=change_to.split("/")
    
  #rules like "Labaratuar/Labaratuvar -> Laboratuvar"
  if len(from_parts)>0 and len(to_parts)==1:
    for from_part in from_parts:
      regex = re.compile(r"\b"+from_part+r"\b")
      replacement_rules.append({
          "regex":regex,
          "change_from":from_part.strip(),
          "change_to":change_to,
          "message":parsed["message"]
      }) 
  elif len(from_parts)==len(to_parts):
    i=0
    while i<len(from_parts):
        from_part = from_parts[i].strip()
        to_part = to_parts[i].strip()
        regex = re.compile(r"\b"+from_part+r"\b")
        replacement_rules.append({
          "regex":regex,
          "change_from":from_part,
          "change_to":to_part,
          "message":parsed["message"]
        }) 
        
        i=i+1
  else:
    print("don't know how to interpret rule '"+parsed["message"]+"'.")



    
# suffix rules ...A -> ...B
for line in replacements_regex_end:
  parsed = parseline(line)
  change_from=parsed["src"].replace("...","")
  regex = re.compile(change_from+r"\b")
  replacement_rules.append({
      "regex":regex,
      "change_from":parsed["src"],
      "change_to":parsed["dst"],
      "message":parsed["message"]
  }) 
   
# prefix rules ...A -> ...B
for line in replacements_regex_start:
  parsed = parseline(line)
  change_from=parsed["src"].replace("...","")
  regex = re.compile(r"\b"+change_from)
  replacement_rules.append({
      "regex":regex,
      "change_from":parsed["src"],
      "change_to":parsed["dst"],
      "message":parsed["message"]
  })

# %%
# !pip install emoji

import os
import urllib.request
from IPython.display import Markdown, display
from emoji import UNICODE_EMOJI
# Out:
# Collecting emoji
#   Downloading https://files.pythonhosted.org/packages/ff/1c/1f1457fe52d0b30cbeebfd578483cedb3e3619108d2d5a21380dfecf8ffd/emoji-0.6.0.tar.gz (51kB)
#      |████████████████████████████████| 51kB 2.7MB/s
# Building wheels for collected packages: emoji
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-0.6.0-cp36-none-any.whl size=49716 sha256=9ab6a9cafc1ac940255e2d03287d958a829c4c04d030f7ff579a58b6483cf164
#   Stored in directory: /root/.cache/pip/wheels/46/2c/8b/9dcf5216ca68e14e0320e283692dce8ae321cdc01e73e17796
# Successfully built emoji
# Installing collected packages: emoji
# Successfully installed emoji-0.6.0

# %%
print("downloading Turkish sentences from tatoeba")
urllib.request.urlretrieve('https://downloads.tatoeba.org/exports/per_language/tur/tur_sentences_detailed.tsv.bz2', 'tur_sentences_detailed.tsv.bz2')

# !rm -rf /content/tur_sentences_detailed.tsv

print("decompressing data")
# !bunzip2 /content/tur_sentences_detailed.tsv.bz2
print("done")
# Out:
# downloading Turkish sentences from tatoeba
# decompressing data
# done

# %%
import re
import pandas as pd
from io import StringIO

df = pd.read_csv("/content/tur_sentences_detailed.tsv",names=["k","v","user","added","modified"],delimiter="\t")

# %%
def has_emoji(s):
    count = 0
    for emoji in UNICODE_EMOJI:
        count += s.count(emoji)
        if count >= 1:
            return True
    return False

errors={}

# checks for "mi/sina" li sentences, and roughly for sentences with an "e" but without a "li"/"o"/"mi"/"sina"
def validate_sentence(s,index,user):    
  s_lower=toLower_turkish(s)
  if user not in errors:
    errors[user]=[]

  for replacement_data in replacement_rules:
    regex=replacement_data["regex"]
    if regex.search(s_lower):
      errors[user].append([s,index,replacement_data["message"]])

    

freq={}
links={}
id_table={}

from ipywidgets import IntProgress
from IPython.display import display
f = IntProgress(min=0, max=len(df),description="searching...") # instantiate the bar

display(f) # display the bar

def printm(s):
  global output
  output=output+"\n"+s;
    
i=0
for index, row in df.iterrows():
  id_table[index]=row
  user = row['user']
  sentence=row['v']
  validate_sentence(sentence,index,user)
  i=i+1
  if (i%1000)==0:
        f.value=i

print("all sentences processed")

import datetime
from ipywidgets import IntProgress
from IPython.display import display

output="# Tatoeba Turkish Spellcheck Report\n\n"+str(datetime.datetime.now())+"\n\n"



for u in errors:
  errorlist = errors[u]
  if len(errorlist)==0:
    continue
  printm("\n")
  printm("***")
  printm(" \n")
  printm("### Likely Error report for user ["+u+"](https://tatoeba.org/eng/user/profile/"+u+").")
  printm("\n")
  for error in errorlist:
    printm(""+error[0]+"  ")
    printm("- "+str(error[2])+"  ")
    printm("- http://tatoeba.org/eng/sentences/show/"+str(error[1])+"  ")
    printm("")

display(Markdown(output))

print("done")
# Out:
# IntProgress(value=0, description='searching...', max=691755)
# all sentences processed
# # Tatoeba Turkish Spellcheck Report
#
# 2020-11-25 13:35:46.971801
#
#
#
#
# ***
#
#
# ### Likely Error report for user [ritualesatanum](https://tatoeba.org/eng/user/profile/ritualesatanum).
#
#
# Tom her gece Mary'i arıyor.
# - Mary'i -> Mary'yi (Telaffuza göre görüş farkı olabilir)
# - http://tatoeba.org/eng/sentences/show/8421700
#
#
#
# ***
#
#
# ### Likely Error report for user [duran](https://tatoeba.org/eng/user/profile/duran).
#
#
# Kesinlikle Tom'un sigortası atmış.
# - Atmış -> Altmış (çoğu false positive)
# - http://tatoeba.org/eng/sentences/show/1197858
#
# Bir sigorta atmış.
# - Atmış -> Altmış (çoğu false positive)
# - http://tatoeba.org/eng/sentences/show/1253431
#
# Benim birsürü kitabım var.
# - Birsürü -> Bir sürü
# - http://tatoeba.org/eng/sentences/show/1255925
#
# Babamın birsürü kitabı var.
# - Birsürü -> Bir sürü
# - http://tatoeba.org/eng/sentences/show/1285091
#
# Bacak bacak üstüne atmış şekilde orada oturdu.
# - Atmış -> Altmış (çoğu false positive)
# - http://tatoeba.org/eng/sentences/show/1649868
#
# Sigorta atmış.
# - Atmış -> Altmış (çoğu false positive)
# - http://tatoeba.org/eng/sentences/show/2050842
#
# Tom yatakta bacak bacak üstüne atmış oturuyordu.
# - Atmış -> Altmış (çoğu false positive)
# - http://tatoeba.org/eng/sentences/show/3949083
#
# Bunu temizlemek bir sürü zaman, kan, ter ve göz yaşı aldı.
# - Göz yaşı -> Gözyaşı
# - http://tatoeba.org/eng/sentences/show/4639648
#
# Philip, Andrew ve Peter gibi, Bethesda kasabasındandı.
# - ...sda -> ...sta
# - http://tatoeba.org/eng/sentences/show/5405522
#
# Tom kanepede bacak bacak üstüne atmış oturuyordu.
# - Atmış -> Altmış (çoğu false positive)
# - http://tatoeba.org/eng/sentences/show/6551738
#
#
#
# ***
#
#
# ### Likely Error report for user [soliloquist](https://tatoeba.org/eng/user/profile/soliloquist).
#
#
# Ali kendini yere atmış. Pozisyonun penaltıyla uzaktan yakından alakası yok.
# - Atmış -> Altmış (çoğu false positive)
# - http://tatoeba.org/eng/sentences/show/6993723
#
# Golü kim atmış?
# - Atmış -> Altmış (çoğu false positive)
# - http://tatoeba.org/eng/sentences/show/7162702
#
# Bir deli kuyuya taş atmış, kırk akıllı çıkaramamış.
# - Atmış -> Altmış (çoğu false positive)
# - http://tatoeba.org/eng/sentences/show/7225036
#
# Eşeğe cilve yap demişler, çifte atmış.
# - Atmış -> Altmış (çoğu false positive)
# - http://tatoeba.org/eng/sentences/show/7251343
#
# Kardeş kardeşi atmış, yar başında tutmuş.
# - Atmış -> Altmış (çoğu false positive)
# - http://tatoeba.org/eng/sentences/show/7304132
#
# İlk golü kim atmış?
# - Atmış -> Altmış (çoğu false positive)
# - http://tatoeba.org/eng/sentences/show/7591497
#
# Ali işkembeden atmış.
# - Atmış -> Altmış (çoğu false positive)
# - http://tatoeba.org/eng/sentences/show/7893244
#
# Rezil görünüyorsun, hasta mı oldun?'' - ''Pek sayılmaz, akşamdan kalmayım.''	quagliarella	2019-06-15 16:09:00	2019-06-15 16:09:00
# 7980616	tur	Akşamdan kalma baş ağrısıyla uyanmak kadar kötü bir şey yok.	quagliarella	2019-06-15 16:10:03	2019-06-15 16:10:16
# 7980622	tur	Bu mavi mi?	SadeceTurkce	2019-06-15 16:13:11	2019-06-15 16:13:11
# 7980649	tur	Yine aynı görüşteyiz.	soliloquist	2019-06-15 16:48:23	2019-06-15 16:48:23
# 7980659	tur	Tom kerhaneye gitti.	soliloquist	2019-06-15 16:50:45	2019-06-15 16:50:45
# 7980667	tur	Tom çark etti.	soliloquist	2019-06-15 16:55:25	2019-06-15 16:55:25
# 7980668	tur	Tom tornistan etti.	soliloquist	2019-06-15 16:55:32	2019-06-15 16:55:32
# 7980669	tur	Tom geri vites yaptı.	soliloquist	2019-06-15 16:55:49	2019-06-15 16:55:49
# 7980673	tur	Tom gölde taş sektirdi.	soliloquist	2019-06-15 16:56:55	2019-06-15 16:56:55
# 7980676	tur	Tom bana suda taş sektirmeyi öğretti.	soliloquist	2019-06-15 16:58:46	2019-06-15 16:58:46
# 7980681	tur	Avusturya etrafı karayla çevrili bir ülke mi?	soliloquist	2019-06-15 17:00:38	2019-06-15 17:00:38
# 7980683	tur	Avustralya etrafı karayla çevrili bir ülke mi?	soliloquist	2019-06-15 17:00:59	2019-06-15 17:01:13
# 7981421	tur	Ben baraja yakın bir yerde yaşıyorum.	quagliarella	2019-06-16 06:15:41	2019-06-16 06:15:41
# 7981422	tur	Eğer baraj çökerse binlerce insan hayatını kaybedebilir.	quagliarella	2019-06-16 06:16:41	2019-06-16 06:16:41
# 7981423	tur	Ağaçların hep kuzeye bakan yanı yosun tutacak diye bir şey yok.	quagliarella	2019-06-16 06:21:28	2019-06-16 06:21:28
# 7981883	tur	Kendinizi benim planlarıma göre ayarlamak durumundasınız.	quagliarella	2019-06-16 12:36:12	2019-06-16 12:36:12
# 7981884	tur	Benim planlarıma uymanız gerekiyor.	quagliarella	2019-06-16 12:36:26	2019-06-16 12:36:26
# 7982174	tur	Dışarısı buz gibi.	soliloquist	2019-06-16 14:34:22	2019-06-16 14:34:22
# 7982175	tur	Tom bunu yaptığını hatırladı.	soliloquist	2019-06-16 14:37:29	2019-06-16 14:37:29
# 7982178	tur	Onlarla saat altıda buluşacağım.	soliloquist	2019-06-16 14:40:19	2019-06-16 14:40:19
# 7982180	tur	Tom bir şey kaçırdı mı?	soliloquist	2019-06-16 14:42:23	2019-06-16 14:42:23
# 7982181	tur	Yerel bir âdet bu.	soliloquist	2019-06-16 14:43:23	2019-06-16 14:43:37
# 7982184	tur	Tom bir Lichtenberg figürü yaptı.	soliloquist	2019-06-16 14:44:36	2019-06-16 14:44:36
# 7982187	tur	Tom bir pirografi sanatçısı.	soliloquist	2019-06-16 14:45:05	2019-06-16 14:45:05
# 7982189	tur	Tom bir ahşap yakma sanatçısı.	soliloquist	2019-06-16 14:45:30	2019-06-16 14:45:30
# 7982193	tur	Mary bir ebru sanatçısı.	soliloquist	2019-06-16 14:46:17	2019-06-16 14:46:17
# 7982195	tur	Tom bir aşı karşıtı.	soliloquist	2019-06-16 14:48:31	2019-06-16 14:48:31
# 7982197	tur	Geldikleri gibi giderler.	soliloquist	2019-06-16 14:49:23	2019-06-16 14:49:23
# 7982198	tur	Saygılar.	soliloquist	2019-06-16 14:49:39	2019-06-16 14:49:39
# 7982199	tur	Hürmetler.	soliloquist	2019-06-16 14:49:46	2019-06-16 14:49:46
# 7982200	tur	Bunu bilen kişi sayısı bir elin parmaklarını geçmez.	soliloquist	2019-06-16 14:50:02	2019-06-16 14:50:02
# 7982201	tur	Bir ipte iki cambaz oynamaz.	soliloquist	2019-06-16 14:50:12	2019-06-16 14:50:12
# 7982203	tur	Tom insan selini yara yara ilerledi.	soliloquist	2019-06-16 14:50:41	2019-06-16 14:50:41
# 7982204	tur	Ali tok evin aç kedisi gibi davranıyor.	soliloquist	2019-06-16 14:51:28	2019-06-16 14:51:28
# 7982205	tur	Ali'den şüphelenen gitsin abdestini tazelesin.	soliloquist	2019-06-16 14:52:22	2019-06-16 14:52:22
# 7982206	tur	Avucunu yalarsın.	soliloquist	2019-06-16 14:52:39	2019-06-16 14:52:39
# 7982207	tur	Ali avucunu yaladı.	soliloquist	2019-06-16 14:52:57	2019-06-16 14:52:57
# 7982208	tur	Ali arabanın motoruna giren kediyi kurtardı.	soliloquist	2019-06-16 14:53:21	2019-06-16 14:53:21
# 7982209	tur	Ali'yle taso oynadık.	soliloquist	2019-06-16 14:53:33	2019-06-16 14:53:33
# 7982210	tur	Ali'yle misket oynadık.	soliloquist	2019-06-16 14:53:40	2019-06-16 14:53:40
# 7982211	tur	Ali'yle okey oynadık.	soliloquist	2019-06-16 14:53:47	2019-06-16 14:53:47
# 7982212	tur	Ali'yle pişti oynadık.	soliloquist	2019-06-16 14:53:55	2019-06-16 14:53:55
# 7982213	tur	Ali'yle taş-kâğıt-makas oynadık.	soliloquist	2019-06-16 14:54:02	2019-06-16 14:54:02
# 7982214	tur	Ali'nin başına taş düştü galiba.	soliloquist	2019-06-16 14:54:18	2019-06-16 14:54:18
# 7982215	tur	Bizi gömdüler, ama tohum olduğumuzu unuttular.	soliloquist	2019-06-16 14:55:02	2019-06-16 14:55:02
# 7982216	tur	Bizi kestiler, ama kesildikçe sakal gibi daha gür çıkacağımızı unuttular.	soliloquist	2019-06-16 14:55:43	2019-06-16 14:55:43
# 7982217	tur	Tom pastayı kesti.	soliloquist	2019-06-16 14:58:28	2019-06-16 14:58:28
# 7982218	tur	Tom'un sesi çok iyimser değildi.	soliloquist	2019-06-16 15:00:47	2019-06-16 15:00:47
# 7982219	tur	Mağaraya tek başıma girmekten korkuyorum.	soliloquist	2019-06-16 15:01:37	2019-06-16 15:01:37
# 7982220	tur	Tom yaralı bir hayvanı kurtardı.	soliloquist	2019-06-16 15:02:12	2019-06-16 15:02:12
# 7983800	tur	Matematiğim hiç iyi değil.	soliloquist	2019-06-17 12:54:46	2019-06-17 12:54:46
# 7983802	tur	Matematikten hiç anlamam.	soliloquist	2019-06-17 12:54:58	2019-06-17 12:54:58
# 7983804	tur	Tom'un göz bebekleri büyüdü.	soliloquist	2019-06-17 12:56:02	2019-06-17 12:56:02
# 7983814	tur	Mary'nin bebeğinin cinsiyeti belli oldu.	soliloquist	2019-06-17 13:03:35	2019-06-17 13:03:35
# 7983815	tur	Ali fenalık geçirdi.	soliloquist	2019-06-17 13:06:09	2019-06-17 13:06:09
# 7983816	tur	Ali baygınlık geçirdi.	soliloquist	2019-06-17 13:07:01	2019-06-17 13:07:01
# 7983817	tur	Güldürdün.	soliloquist	2019-06-17 13:07:14	2019-06-17 13:07:14
# 7983818	tur	Sesli güldüm.	soliloquist	2019-06-17 13:07:35	2019-06-17 13:07:35
# 7983819	tur	İlahi Ali!	soliloquist	2019-06-17 13:07:46	2019-06-17 13:07:46
# 7983820	tur	İlahi sen!	soliloquist	2019-06-17 13:07:52	2019-06-17 13:07:52
# 7983821	tur	Biz de yedik.	soliloquist	2019-06-17 13:08:07	2019-06-17 13:08:07
# 7983824	tur	Sami canlı müzik yapıyor.	soliloquist	2019-06-17 13:10:25	2019-06-17 13:10:25
# 7983825	tur	Sami bir canlı müzik sanatçısı.	soliloquist	2019-06-17 13:10:38	2019-06-17 13:10:38
# 7984263	tur	Mısır'ın demokratik yollarla seçilen ilk cumhurbaşkanı Muhammed Mursi mahkemede hayatını kaybetti.	soliloquist	2019-06-17 17:01:35	2019-06-17 17:01:35
# 7984266	tur	O kadar genç değilim.	soliloquist	2019-06-17 17:03:22	2019-06-17 17:03:22
# 7984267	tur	Yaşım o kadar küçük değil.	soliloquist	2019-06-17 17:03:30	2019-06-17 17:03:30
# 7984270	tur	Tom çiçek dikiyor.	soliloquist	2019-06-17 17:03:55	2019-06-17 17:03:55
# 7986011	tur	Korkmamıştım.	soliloquist	2019-06-18 12:42:59	2019-06-18 12:42:59
# 7986012	tur	Çok fazla ödevim var.	soliloquist	2019-06-18 12:43:13	2019-06-18 12:43:13
# 7986013	tur	Bir yığın ödevim var.	soliloquist	2019-06-18 12:43:35	2019-06-18 12:43:35
# 7986014	tur	Bu nehirde yüzmeyi sevmiyorum.	soliloquist	2019-06-18 12:43:50	2019-06-18 12:43:50
# 7986015	tur	Niye hep böyle sabırsızsın?	soliloquist	2019-06-18 12:44:12	2019-06-18 12:44:12
# 7986016	tur	Fındık fıstık yemeyi severim.	soliloquist	2019-06-18 12:45:59	2019-06-18 12:45:59
# 7986017	tur	Kuruyemiş yemeyi severim.	soliloquist	2019-06-18 12:47:09	2019-06-18 12:47:09
# 7986018	tur	Tom müze gezmeye bayılır.	soliloquist	2019-06-18 12:49:09	2019-06-18 12:49:09
# 7986021	tur	Tom fatura istedi.	soliloquist	2019-06-18 12:49:58	2019-06-18 12:49:58
# 7986022	tur	Tom fiş istedi.	soliloquist	2019-06-18 12:50:04	2019-06-18 12:50:04
# 7986027	tur	Tom makbuz istedi.	soliloquist	2019-06-18 12:50:23	2019-06-18 12:50:23
# 7986031	tur	Dikkat et de şu taşa takılma.	soliloquist	2019-06-18 12:51:17	2019-06-18 12:51:17
# 7986036	tur	Ali laf kalabalığı yapıyor.	soliloquist	2019-06-18 12:52:14	2019-06-18 12:52:14
# 7986039	tur	Laf kalabalğı yapma.	soliloquist	2019-06-18 12:52:25	2019-06-18 12:52:25
# 7986040	tur	Ali kuru gürültü yapıyor.	soliloquist	2019-06-18 12:52:33	2019-06-18 12:52:33
# 7986041	tur	Bunların hepsi kuru gürültü.	soliloquist	2019-06-18 12:52:53	2019-06-18 12:52:53
# 7986042	tur	Ali sazı eline aldı.	soliloquist	2019-06-18 12:53:00	2019-06-18 12:53:00
# 7986043	tur	Ali hızını alamadı.	soliloquist	2019-06-18 12:53:10	2019-06-18 12:53:10
# 7986048	tur	Ali banka hortumlayıp yurt dışına kaçtı.	soliloquist	2019-06-18 12:53:24	2019-06-18 12:53:24
# 7986063	tur	Tom kraldan çok kralcıdır.	soliloquist	2019-06-18 12:56:47	2019-06-18 12:56:47
# 7986065	tur	Tom kraldan çok kralcılık yapıyor.	soliloquist	2019-06-18 12:56:59	2019-06-18 12:56:59
# 7986071	tur	Çabuk korkarım.	soliloquist	2019-06-18 12:59:07	2019-06-18 12:59:07
# 7986073	tur	Tom çevirmenlik yapıyor.	soliloquist	2019-06-18 12:59:39	2019-06-18 12:59:40
# 7986076	tur	Tom tercüman olarak çalışıyor.	soliloquist	2019-06-18 13:00:14	2019-06-18 13:00:14
# 7986078	tur	Eski karım yeni ilişkimi bozmak istiyor.	soliloquist	2019-06-18 13:00:42	2019-06-18 13:00:42
# 7986082	tur	İsteyen herkes gelebilir.	soliloquist	2019-06-18 13:02:20	2019-06-18 13:02:20
# 7986085	tur	Tom köpeğime taş attı.	soliloquist	2019-06-18 13:03:07	2019-06-18 13:03:07
# 7986087	tur	Tom ve Mary koruyucu ailelik yapıyor.	soliloquist	2019-06-18 13:04:20	2019-06-18 13:04:20
# 7986088	tur	Bence Boston güvenli bir şehir.	soliloquist	2019-06-18 13:05:47	2019-06-18 13:05:47
# 7986117	tur	Haydut hak ettiğini aldı.	quagliarella	2019-06-18 13:22:37	2019-06-18 13:22:37
# 7986265	tur	Mutluluk paha biçilemezdir.	quagliarella	2019-06-18 13:58:10	2019-06-18 13:58:10
# 7986282	tur	Tecrübeli bir insanın nasihatına paha biçilemez.	quagliarella	2019-06-18 14:02:32	2019-06-18 14:02:32
# 7986295	tur	Arkadaşlar ikiye ayrılır: Parayla satın alınabilenler ve parayla satın alınamayanlar.	quagliarella	2019-06-18 14:07:19	2019-06-18 14:07:19
# 7986323	tur	Tom içinde bulunduğu sinirli hâlden biraz çıkmıştı bile.	quagliarella	2019-06-18 14:12:17	2019-06-18 14:12:17
# 7986326	tur	Tom birazcık sakinlemeye başlamıştı bile.	quagliarella	2019-06-18 14:13:00	2019-06-18 14:13:00
# 7986510	tur	10 artı 10 eşittir 100.	soliloquist	2019-06-18 15:39:06	2019-06-18 15:39:06
# 7986512	tur	Sami için gıyabi cenaze namazı kılındı.	soliloquist	2019-06-18 15:42:01	2019-06-18 15:42:01
# 7986515	tur	Yapılışını gördüm.	soliloquist	2019-06-18 15:46:19	2019-06-18 15:46:19
# 7986516	tur	Yapılırken gördüm.	soliloquist	2019-06-18 15:46:30	2019-06-18 15:52:23
# 7986517	tur	Hiç uykum yok.	soliloquist	2019-06-18 15:47:50	2019-06-18 15:47:50
# 7986518	tur	Hiç uykum gelmedi.	soliloquist	2019-06-18 15:47:57	2019-06-18 15:47:57
# 7986521	tur	Aslan ve kaplanlara büyük kediler denir.	soliloquist	2019-06-18 15:49:58	2019-06-18 15:49:58
# 7986522	tur	Paramı Tom'a emanet ettim.	soliloquist	2019-06-18 15:50:40	2019-06-18 15:50:40
# 7986524	tur	Fazla kalmayacağız.	soliloquist	2019-06-18 15:51:16	2019-06-18 15:51:16
# 7986620	tur	Bir kuş gibi özgürüm.	SadeceTurkce	2019-06-18 18:14:32	2019-06-18 18:14:32
# 7986658	tur	Bir yıldız doğuyor.	SadeceTurkce	2019-06-18 18:45:03	2019-06-18 18:45:03
# 7986702	tur	Bir kuş şarkı söylüyor.	SadeceTurkce	2019-06-18 19:25:42	2019-06-18 19:25:42
# 7986707	tur	iPhone'un olsun ister misin?	SadeceTurkce	2019-06-18 19:26:22	2019-06-18 19:26:22
# 7986713	tur	O bir pop yıldızı.	SadeceTurkce	2019-06-18 19:27:37	2019-06-18 19:27:37
# 7986923	tur	Tom yağmurlu havalarda otobüse biner.	soliloquist	2019-06-18 21:15:48	2019-06-18 21:15:57
# 7986928	tur	Tom bir çete üyesi.	soliloquist	2019-06-18 21:16:27	2019-06-18 21:16:27
# 7986932	tur	Muhafazakâr olduğunu biliyorum.	soliloquist	2019-06-18 21:17:03	2019-06-18 21:17:03
# 7986933	tur	Bu ekmek büyüktür.	abdullahkasit	2019-06-18 21:17:11	2019-06-18 21:17:11
# 7986939	tur	Çirkindim.	abdullahkasit	2019-06-18 21:19:25	2019-06-18 21:19:25
# 7986941	tur	Onun gibi bir şey.	soliloquist	2019-06-18 21:20:08	2019-06-18 21:20:08
# 7986944	tur	Kim satıyor?	abdullahkasit	2019-06-18 21:21:33	2019-06-18 21:21:33
# 7986946	tur	Ortam süper.	soliloquist	2019-06-18 21:21:43	2019-06-18 21:21:43
# 7986948	tur	Ali'yle ayak üstü konuştuk biraz.	soliloquist	2019-06-18 21:22:32	2019-06-18 21:22:32
# 7986949	tur	Ali sıfırı tüketti.	soliloquist	2019-06-18 21:22:48	2019-06-18 21:22:48
# 7986951	tur	Ali cepten yiyor.	soliloquist	2019-06-18 21:23:01	2019-06-18 21:23:01
# 7986952	tur	Ali kafasızlık etmiş.	soliloquist	2019-06-18 21:23:27	2019-06-18 21:23:27
# 7986954	tur	O oğluna büyük bir miras bırakıyor.	abdullahkasit	2019-06-18 21:24:08	2019-06-18 21:24:08
# 7986958	tur	Bu problemin aynısını ben de yaşadım.	soliloquist	2019-06-18 21:26:47	2019-06-18 21:27:19
# 7986959	tur	Bu sorunun aynısı benim de başıma geldi.	soliloquist	2019-06-18 21:27:12	2019-06-18 21:27:12
# 7987192	tur	Thomas Maria'yı parmağıyla gösterdi.	abdullahkasit	2019-06-19 07:32:04	2019-06-19 07:32:04
# 7987193	tur	Thomas kılıcı düşürdü.	abdullahkasit	2019-06-19 07:38:37	2019-06-19 07:38:37
# 7987207	tur	Adam bazen şakayla gerçeği anlatır.	abdullahkasit	2019-06-19 07:50:01	2019-06-19 07:50:01
# 7987210	tur	İnsan bazen şakayla gerçeği anlatır.	abdullahkasit	2019-06-19 07:51:20	2019-06-19 07:51:29
# 7987497	tur	Çay buz gibi oldu.	quagliarella	2019-06-19 10:41:38	2019-06-19 10:41:38
# 7987500	tur	Çay epeydir soğuyor.	quagliarella	2019-06-19 10:42:07	2019-06-19 10:42:07
# 7987686	tur	Sen her şeyi mahvediyorsun!	quagliarella	2019-06-19 11:37:25	2019-06-19 11:37:25
# 7987743	tur	Maçı idare ediyoruz.	quagliarella	2019-06-19 11:53:33	2019-06-19 11:53:33
# 7987774	tur	Her insanın kaderi kendi ellerindedir.	quagliarella	2019-06-19 12:10:52	2019-06-19 12:10:52
# 7987978	tur	O sessizce güldü.	ltempa	2019-06-19 13:49:44	2019-06-19 13:49:44
# 7988005	tur	Zindan insanın zihnindedir,aklındadır.	ltempa	2019-06-19 14:06:23	2019-06-19 14:06:23
# 7988006	tur	Gitmen gerek.	ltempa	2019-06-19 14:06:51	2019-06-19 14:06:51
# 7988007	tur	Bu arabanın fiyatı ne kadar ?	ltempa	2019-06-19 14:07:32	2019-06-19 14:07:32
# 7988067	tur	Niye bu kadar uzadı?	soliloquist	2019-06-19 14:46:09	2019-06-19 14:46:09
# 7988074	tur	İşi ehline verin.	soliloquist	2019-06-19 14:48:49	2019-06-19 14:48:49
# 7988075	tur	Şehre inen ayı kameralara yansıdı.	soliloquist	2019-06-19 14:49:01	2019-06-19 14:49:25
# 7988077	tur	Ali'nin alacağı para dudak uçuklattı.	soliloquist	2019-06-19 14:49:35	2019-06-19 14:49:35
# 7988081	tur	Tom bunu kaldıramadı.	soliloquist	2019-06-19 14:51:06	2019-06-19 14:51:06
# 7988082	tur	Tom bununla yaşayamaz.	soliloquist	2019-06-19 14:52:15	2019-06-19 14:52:15
# 7988083	tur	Tom tek başına seyahate çıktı.	soliloquist	2019-06-19 14:52:49	2019-06-19 14:52:49
# 7988089	tur	Niye benden yardım istemedin?	soliloquist	2019-06-19 14:56:07	2019-06-19 14:56:07
# 7988090	tur	Sami, Leyla'nın saçını çekti.	soliloquist	2019-06-19 14:56:22	2019-06-19 14:56:22
# 7988091	tur	Birçok Amerikalı, Türkiye'nin haritadaki yerini bile bilmez.	soliloquist	2019-06-19 14:59:26	2019-06-19 14:59:26
# 7988099	tur	Wikipedia'daki Turkish Americans" başlığı eskiden "Turks in America" şeklindeydi.
# - ...kce -> ...kçe
# - http://tatoeba.org/eng/sentences/show/7980614
#
# Ali nişanı atmış.
# - Atmış -> Altmış (çoğu false positive)
# - http://tatoeba.org/eng/sentences/show/8335204
#
# Ali bol keseden atmış.
# - Atmış -> Altmış (çoğu false positive)
# - http://tatoeba.org/eng/sentences/show/8348290
#
# Ali çok yüksekten atmış.
# - Atmış -> Altmış (çoğu false positive)
# - http://tatoeba.org/eng/sentences/show/8368896
#
# Ali yeni şarkısında bana taş atmış.
# - Atmış -> Altmış (çoğu false positive)
# - http://tatoeba.org/eng/sentences/show/8533814
#
# Ali yine kurusıkı atmış.
# - Atmış -> Altmış (çoğu false positive)
# - http://tatoeba.org/eng/sentences/show/8545502
#
#
#
# ***
#
#
# ### Likely Error report for user [deyta](https://tatoeba.org/eng/user/profile/deyta).
#
#
# Lise, İngilizce High School'dur.High School ise Türkçe Yüksek Okul'dur.Yüksek Okul Üniversite midir?
# - Yüksek okul -> Yüksekokul
# - http://tatoeba.org/eng/sentences/show/2474029
#
# Hiç bir tarlayı bir atla sürdün mü?
# - Hiç bir -> Hiçbir
# - http://tatoeba.org/eng/sentences/show/3311548
#
# Tom hiç bir sirke gitmedi.
# - Hiç bir -> Hiçbir
# - http://tatoeba.org/eng/sentences/show/3366103
#
# Dresden, Elbe'deki Floransa olarak bilinirdi.
# - ...sden -> ...sten
# - http://tatoeba.org/eng/sentences/show/3476394
#
# Tom Alaska'ya taşınana kadar hiç bir geyik görmemişti.
# - Hiç bir -> Hiçbir
# - http://tatoeba.org/eng/sentences/show/4018015
#
# Bu gün Cuma.
# - Bu gün -> Bugün
# - http://tatoeba.org/eng/sentences/show/4045463
#
# Öğretmen "Sınav gelecek hafta bu gün yapılacak" dedi.
# - Bu gün -> Bugün
# - http://tatoeba.org/eng/sentences/show/4246398
#
# Betin benzin atmış.
# - Atmış -> Altmış (çoğu false positive)
# - http://tatoeba.org/eng/sentences/show/4406828
#
# Bir filim var.
# - Filim -> Film
# - http://tatoeba.org/eng/sentences/show/4423343
#
# Ben hiç bir oyun yazmadım.
# - Hiç bir -> Hiçbir
# - http://tatoeba.org/eng/sentences/show/4749200
#
# Bu gün son derece yorucuydu.
# - Bu gün -> Bugün
# - http://tatoeba.org/eng/sentences/show/4755442
#
# Benim filim nerede?
# - Filim -> Film
# - http://tatoeba.org/eng/sentences/show/4756473
#
# Sonunda buluştuk! Ben bu gün için çok uzun süre bekledim!
# - Bu gün -> Bugün
# - http://tatoeba.org/eng/sentences/show/4764086
#
# FDA yeni ilacı onayladı.
# - ...fda -> ...fta
# - http://tatoeba.org/eng/sentences/show/5269710
#
# Hiç bir Dvorak klavye kullandınız mı?
# - Hiç bir -> Hiçbir
# - http://tatoeba.org/eng/sentences/show/5305565
#
# Hiç bir kılıç kırlangıcı gördünüz mü?
# - Hiç bir -> Hiçbir
# - http://tatoeba.org/eng/sentences/show/5316577
#
# Biz bu gün atalarımızın mezarlarını ziyaret ediyoruz.
# - Bu gün -> Bugün
# - http://tatoeba.org/eng/sentences/show/5335690
#
# Sen hiç bir penis emdin mi?
# - Hiç bir -> Hiçbir
# - http://tatoeba.org/eng/sentences/show/5442281
#
# Dresden, 1945'te bombalandı.
# - ...sden -> ...sten
# - http://tatoeba.org/eng/sentences/show/5550080
#
# Tom hayatında hiç bir hikaye anlatmadı.
# - Hiç bir -> Hiçbir
# - http://tatoeba.org/eng/sentences/show/5864299
#
# Fadıl'ın aç gözlü bir kız arkadaşı vardı.
# - Aç gözlü -> Açgözlü
# - http://tatoeba.org/eng/sentences/show/5880307
#
# Hiç bir gemide bulunmadım.
# - Hiç bir -> Hiçbir
# - http://tatoeba.org/eng/sentences/show/5955400
#
# Ben hiç bir havuzda yüzmedim.
# - Hiç bir -> Hiçbir
# - http://tatoeba.org/eng/sentences/show/5955458
#
# Bu gün için çok uzun süredir bekliyorum.
# - Bu gün -> Bugün
# - http://tatoeba.org/eng/sentences/show/6042094
#
# Bu bir çok terimli mi?
# - Bir çok -> Birçok
# - http://tatoeba.org/eng/sentences/show/6064065
#
# Hiç bir adada yaşamak istedin mi?
# - Hiç bir -> Hiçbir
# - http://tatoeba.org/eng/sentences/show/6130381
#
#
#
# ***
#
#
# ### Likely Error report for user [maydoo](https://tatoeba.org/eng/user/profile/maydoo).
#
#
# O hiç bir erkekle sevişti mi?
# - Hiç bir -> Hiçbir
# - http://tatoeba.org/eng/sentences/show/3249796
#
# Hiç bir damla alkol almadım.
# - Hiç bir -> Hiçbir
# - http://tatoeba.org/eng/sentences/show/3741017
#
# Japonya'da birsürü aktif volkan var.
# - Birsürü -> Bir sürü
# - http://tatoeba.org/eng/sentences/show/4416148
#
# Arapça yazamam. Arapca bir klavyem yok.
# - ...pca -> ...pça
# - http://tatoeba.org/eng/sentences/show/4648802
#
# Dışarıda birsürü insan var.
# - Birsürü -> Bir sürü
# - http://tatoeba.org/eng/sentences/show/4733699
#
# Birsürü insan Tokyo'da yaşıyor.
# - Birsürü -> Bir sürü
# - http://tatoeba.org/eng/sentences/show/4827304
#
# Bunun hakkında fikri olmayan birsürü insan var.
# - Birsürü -> Bir sürü
# - http://tatoeba.org/eng/sentences/show/4989617
#
#
#
# ***
#
#
# ### Likely Error report for user [Gulo_Luscus](https://tatoeba.org/eng/user/profile/Gulo_Luscus).
#
#
# Türkçe Ğ ve İspanyolca H kaçtı ve birlikte birsürü tamamen sessiz çocukları oldu.
# - Birsürü -> Bir sürü
# - http://tatoeba.org/eng/sentences/show/1071227
#
#
#
# ***
#
#
# ### Likely Error report for user [yavuz](https://tatoeba.org/eng/user/profile/yavuz).
#
#
# Hiç bir yerini kırdın mı?
# - Hiç bir -> Hiçbir
# - http://tatoeba.org/eng/sentences/show/3450876
#
#
#
# ***
#
#
# ### Likely Error report for user [ajje](https://tatoeba.org/eng/user/profile/ajje).
#
#
# Hiç bir kimse senin eline su dökemez.
# - Hiç bir -> Hiçbir
# - http://tatoeba.org/eng/sentences/show/8128103
#
#
#
# ***
#
#
# ### Likely Error report for user [User20656](https://tatoeba.org/eng/user/profile/User20656).
#
#
# Hiç bir karavan sürdün mü?
# - Hiç bir -> Hiçbir
# - http://tatoeba.org/eng/sentences/show/3626519
#
#
#
# ***
#
#
# ### Likely Error report for user [murtaza](https://tatoeba.org/eng/user/profile/murtaza).
#
#
# Hiç bir polis memuruna küfür ettin mi?
# - Hiç bir -> Hiçbir
# - http://tatoeba.org/eng/sentences/show/2161334
#
#
#
# ***
#
#
# ### Likely Error report for user [orko](https://tatoeba.org/eng/user/profile/orko).
#
#
# Oğlun şimdiye kadar bayağı boy atmış olmalı.
# - Atmış -> Altmış (çoğu false positive)
# - http://tatoeba.org/eng/sentences/show/2527842
#
#
#
# ***
#
#
# ### Likely Error report for user [evka](https://tatoeba.org/eng/user/profile/evka).
#
#
# Bu gün bana hiç email gelmedi.
# - Bu gün -> Bugün
# - http://tatoeba.org/eng/sentences/show/6998912
#
#
#
# ***
#
#
# ### Likely Error report for user [sumeyye](https://tatoeba.org/eng/user/profile/sumeyye).
#
#
# Hiç bir araba sattın mı?
# - Hiç bir -> Hiçbir
# - http://tatoeba.org/eng/sentences/show/2638447
#
#
#
# ***
#
#
# ### Likely Error report for user [vvv123](https://tatoeba.org/eng/user/profile/vvv123).
#
#
# Bu gün pazardır.
# - Bu gün -> Bugün
# - http://tatoeba.org/eng/sentences/show/3659089
#
#
#
# ***
#
#
# ### Likely Error report for user [tornado](https://tatoeba.org/eng/user/profile/tornado).
#
#
# Meryem, Tom'un cep telefonunu kazara çamaşır makinesine atmış.
# - Atmış -> Altmış (çoğu false positive)
# - http://tatoeba.org/eng/sentences/show/4483777
#
#
#
# ***
#
#
# ### Likely Error report for user [violetanka](https://tatoeba.org/eng/user/profile/violetanka).
#
#
# Jerry'nin iki yüzlü olduğunu düşünüyorum.
# - İki yüzlü -> İkiyüzlü
# - http://tatoeba.org/eng/sentences/show/4621224
#
#
#
# ***
#
#
# ### Likely Error report for user [ruth_tatoeba](https://tatoeba.org/eng/user/profile/ruth_tatoeba).
#
#
# Bu gün bana gelmen beni mutlu ediyor.
# - Bu gün -> Bugün
# - http://tatoeba.org/eng/sentences/show/6776854
#
#
#
# ***
#
#
# ### Likely Error report for user [tnnglue](https://tatoeba.org/eng/user/profile/tnnglue).
#
#
# Hiç bir kadınla beraber yatmadın mı?
# - Hiç bir -> Hiçbir
# - http://tatoeba.org/eng/sentences/show/4547606
#
# Hiç bir kadınla beraber olmadın mı?
# - Hiç bir -> Hiçbir
# - http://tatoeba.org/eng/sentences/show/4547609
#
# Hiç bir kadınla sevişmedin mi?
# - Hiç bir -> Hiçbir
# - http://tatoeba.org/eng/sentences/show/4547612
#
#
#
# ***
#
#
# ### Likely Error report for user [dursun](https://tatoeba.org/eng/user/profile/dursun).
#
#
# Tom'un Marry'yi beklemekten rahatsız olmayacağını sanıyordum.
# - Marry -> Mary
# - http://tatoeba.org/eng/sentences/show/4850855
#
#
#
# ***
#
#
# ### Likely Error report for user [odien16](https://tatoeba.org/eng/user/profile/odien16).
#
#
# Bizde onlardan birsürü var.
# - Birsürü -> Bir sürü
# - http://tatoeba.org/eng/sentences/show/4968311
#
#
#
# ***
#
#
# ### Likely Error report for user [maqnus](https://tatoeba.org/eng/user/profile/maqnus).
#
#
# Doğal olarak hiç bir dil diğerinden üstün değildir.
# - Hiç bir -> Hiçbir
# - http://tatoeba.org/eng/sentences/show/5927423
#
#
#
# ***
#
#
# ### Likely Error report for user [cengistan](https://tatoeba.org/eng/user/profile/cengistan).
#
#
# Hiç bir yere gitmeyen, hiçbir yere de ulaşamaz.
# - Hiç bir -> Hiçbir
# - http://tatoeba.org/eng/sentences/show/5190857
#
#
#
# ***
#
#
# ### Likely Error report for user [dvdemirel](https://tatoeba.org/eng/user/profile/dvdemirel).
#
#
# Kendimi bir çok şeyden mahrum bırakıyorum ama Tom'a her zaman en iyisini alıyorum.
# - Bir çok -> Birçok
# - http://tatoeba.org/eng/sentences/show/8589830
#
# Tom'un bunu yapmasına müsade edeceğimi sanmıyorum.
# - Müsade -> Müsaade
# - http://tatoeba.org/eng/sentences/show/8591051
#
#
#
# ***
#
#
# ### Likely Error report for user [Bitirim](https://tatoeba.org/eng/user/profile/Bitirim).
#
#
# Ali resmen füze atmış.
# - Atmış -> Altmış (çoğu false positive)
# - http://tatoeba.org/eng/sentences/show/8453780
#
# Ali yeni şarkısında bana diss atmış.
# - Atmış -> Altmış (çoğu false positive)
# - http://tatoeba.org/eng/sentences/show/8453821
#
# Kadınlar kıtalara benzer. 20 yaşındaki kadın Afrika gibidir, bir çok yeri hâlâ keşfedilmemiştir. 30 yaşındaki kadın Asya gibidir; sıcak, esrarengiz ve bereketli. 40 yaşındaki kadın Amerika gibidir; teknik açıdan mükemmel. 50 yaşındaki kadın harp sonrası Avrupa gibidir, bir çok yeri tahrip edilmiştir. 60'ından sonra kadın Antarktika gibidir; bilirsin, ama gitmezsin.
# - Bir çok -> Birçok
# - http://tatoeba.org/eng/sentences/show/8775265
#
# Yerle bir oldum da senle bir olamadım.
# - Senle -> Seninle
# - http://tatoeba.org/eng/sentences/show/8970882
#
#
#
# ***
#
#
# ### Likely Error report for user [MostAssertive1](https://tatoeba.org/eng/user/profile/MostAssertive1).
#
#
# Virginia, bir kadın kocasından sır saklamamalı. "Öyle mi? Ama benden sır saklıyorsun, değil mi? Yoksa senle Mary'den haberim yok mu sanıyordun?" "Ama Virginia!" "Aması falan yok! Derhal evimi terk et ve Mary'yi maçoluğunla tavlamaya devam et, seni adi herif!"
# - Senle -> Seninle
# - http://tatoeba.org/eng/sentences/show/9027949
#
#
#
# ***
#
#
# ### Likely Error report for user [whitekite](https://tatoeba.org/eng/user/profile/whitekite).
#
#
# Tom Mary'e ne tür bir arabası olduğunu sordu.
# - Mary'e -> Mary'ye (Telaffuza göre görüş farkı olabilir)
# - http://tatoeba.org/eng/sentences/show/8988359
#
# Tom Mary'e kendisi için bir sandviç yapması gerektiğini söyledi.
# - Mary'e -> Mary'ye (Telaffuza göre görüş farkı olabilir)
# - http://tatoeba.org/eng/sentences/show/9020685
#
#
#
# ***
#
#
# ### Likely Error report for user [Jum](https://tatoeba.org/eng/user/profile/Jum).
#
#
# Hellowine ýakynlaşýarys we bu gün Hellowin hakynda seniň bilen gürleşip biljegimi pikir etdim.
# - Bu gün -> Bugün
# - http://tatoeba.org/eng/sentences/show/7931713
#
#
#
# ***
#
#
# ### Likely Error report for user [Oldboy](https://tatoeba.org/eng/user/profile/Oldboy).
#
#
# Malesef, cevap basit değil.
# - Malesef -> Maalesef
# - http://tatoeba.org/eng/sentences/show/8468916
#
#
#
# ***
#
#
# ### Likely Error report for user [nedim](https://tatoeba.org/eng/user/profile/nedim).
#
#
# Ne derlerse desinler halen haftaya Avusturalya'ya gitmeyi planlıyorum.
# - Avusturalya -> Avustralya
# - http://tatoeba.org/eng/sentences/show/8609605
#
#
#
# ***
#
#
# ### Likely Error report for user [Cumle_Kurucu](https://tatoeba.org/eng/user/profile/Cumle_Kurucu).
#
#
# Bana komik bir mesaj atmış.
# - Atmış -> Altmış (çoğu false positive)
# - http://tatoeba.org/eng/sentences/show/8490727
#
# Bu yıl ona bir doğumgünü kartı gönderelim.
# - Doğumgünü -> Doğum günü
# - http://tatoeba.org/eng/sentences/show/8533035
#
#
#
# ***
#
#
# ### Likely Error report for user [cartals](https://tatoeba.org/eng/user/profile/cartals).
#
#
# Umarım iyi bir haftasonu geçirirsin.
# - Haftasonu -> Hafta sonu
# - http://tatoeba.org/eng/sentences/show/8456892
#
# Yapabildiğim herhangi bir zaman Avusturalya'ya gitmeye çalışıyorum.
# - Avusturalya -> Avustralya
# - http://tatoeba.org/eng/sentences/show/8457888
#
# Tom'un Avusturalya'da olduğunu mu düşünüyorsun ?
# - Avusturalya -> Avustralya
# - http://tatoeba.org/eng/sentences/show/8459546
#
#
#
# ***
#
#
# ### Likely Error report for user [keremcik](https://tatoeba.org/eng/user/profile/keremcik).
#
#
# Allah bu sabah kaybettiğimiz Amerikalıları kutsasın. Ailelerini yatıştırsın. Allah bu sevdalısı olduğumuz ülkeye gözkulak olsun. Amin.
# - Gözkulak -> Göz kulak
# - http://tatoeba.org/eng/sentences/show/8494900
#
#
#
# ***
#
#
# ### Likely Error report for user [cagri](https://tatoeba.org/eng/user/profile/cagri).
#
#
# Burada ihtiyacım olan herşey var.
# - Herşey -> Her şey
# - http://tatoeba.org/eng/sentences/show/8904790
#
#
#
# ***
#
#
# ### Likely Error report for user [faruk](https://tatoeba.org/eng/user/profile/faruk).
#
#
# Sen burada hiç bir şey bulmayacaksın.
# - Hiç bir -> Hiçbir
# - http://tatoeba.org/eng/sentences/show/8946527
#
#
#
# ***
#
#
# ### Likely Error report for user [aydincan77](https://tatoeba.org/eng/user/profile/aydincan77).
#
#
# O beysbol takımında, değil mi?
# - Beysbol -> Beyzbol
# - http://tatoeba.org/eng/sentences/show/9094546
#
# Tom hiç bir zaman bu kadar çok gülmezdi.
# - Hiç bir -> Hiçbir
# - http://tatoeba.org/eng/sentences/show/9095197
#
#
#
# ***
#
#
# ### Likely Error report for user [tuubaersoy](https://tatoeba.org/eng/user/profile/tuubaersoy).
#
#
# Tom Mary'i tekrar görmek istedi.
# - Mary'i -> Mary'yi (Telaffuza göre görüş farkı olabilir)
# - http://tatoeba.org/eng/sentences/show/9181118
# done
